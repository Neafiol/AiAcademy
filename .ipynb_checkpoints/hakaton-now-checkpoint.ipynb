# %% [markdown]
# ## Описание данных
#
# Архив с данными содержит следующие файлы:
#
# - `sample_submission.csv`: пример файла с решением
# - `train_matches.jsonl`, `test_matches.jsonl`: полные описания матчей ("сырые" данные)
# - `train_features.csv`, `test_features.csv`: таблицы с признаками от организаторов
# - `train_targets.csv`: таблица с исходами матчей из обучающей выборки, в частности указание победителя

# %% [markdown]
# ## Таблицы с признаками от организаторов
#
# Таблицы с признаками были подготовлены организаторами, в них каждый матч описывается его базовыми параметрами, для каждого игрока приведен набор статистик на момент остановки матча. О том как подготовить такую таблицу из сырых данных — смотрите далее.

# %%
import pandas

df_train_features = pandas.read_csv('data_final/train_features.csv', index_col='match_id_hash')
df_train_targets = pandas.read_csv('data_final/train_targets.csv', index_col='match_id_hash')

# %% [markdown]
# В таблице признаков есть колонка-индекс `match_id_hash` (идентификатор матча) и 245 колонок с признаками. Всего примеров матчей в обучающей выборке — почти 40 тысяч. Самый первый признак `game_time` — время когда матч был остановлен (в секундах).

# %%
# размер таблицы
df_train_features.shape
# Out:
# (39675, 245)

# %%
# посмотреть кусочек таблицы
df_train_features.head()
# Out:
#                                   game_time  game_mode  lobby_type  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a        155         22           7
# b9c57c450ce74a2af79c9ce96fac144d        658          4           0
# 6db558535151ea18ca70a6892197db41         21         23           0
# 46a0ddce8f7ed2a8d9bd5edcbb925682        576         22           7
# b1b35ff97723d9b7ade1c9c3cf48f770        453         22           7
#
#                                   objectives_len  chat_len  r1_hero_id  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a               1        11          11
# b9c57c450ce74a2af79c9ce96fac144d               3        10          15
# 6db558535151ea18ca70a6892197db41               0         0         101
# 46a0ddce8f7ed2a8d9bd5edcbb925682               1         4          14
# b1b35ff97723d9b7ade1c9c3cf48f770               1         3          42
#
#                                   r1_kills  r1_deaths  r1_assists  r1_denies  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a         0          0           0          0
# b9c57c450ce74a2af79c9ce96fac144d         7          2           0          7
# 6db558535151ea18ca70a6892197db41         0          0           0          0
# 46a0ddce8f7ed2a8d9bd5edcbb925682         1          0           3          1
# b1b35ff97723d9b7ade1c9c3cf48f770         0          1           1          0
#
#                                       ...        d5_stuns  d5_creeps_stacked  \
# match_id_hash                         ...
# a400b8f29dece5f4d266f49f1ae2e98a      ...        0.000000                  0
# b9c57c450ce74a2af79c9ce96fac144d      ...        0.000000                  0
# 6db558535151ea18ca70a6892197db41      ...        0.000000                  0
# 46a0ddce8f7ed2a8d9bd5edcbb925682      ...        8.664527                  3
# b1b35ff97723d9b7ade1c9c3cf48f770      ...        0.000000                  2
#
#                                   d5_camps_stacked  d5_rune_pickups  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a                 0                0
# b9c57c450ce74a2af79c9ce96fac144d                 0                0
# 6db558535151ea18ca70a6892197db41                 0                0
# 46a0ddce8f7ed2a8d9bd5edcbb925682                 1                3
# b1b35ff97723d9b7ade1c9c3cf48f770                 1                2
#
#                                   d5_firstblood_claimed  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a                      0
# b9c57c450ce74a2af79c9ce96fac144d                      0
# 6db558535151ea18ca70a6892197db41                      0
# 46a0ddce8f7ed2a8d9bd5edcbb925682                      0
# b1b35ff97723d9b7ade1c9c3cf48f770                      0
#
#                                   d5_teamfight_participation  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a                        0.00
# b9c57c450ce74a2af79c9ce96fac144d                        0.00
# 6db558535151ea18ca70a6892197db41                        0.00
# 46a0ddce8f7ed2a8d9bd5edcbb925682                        0.00
# b1b35ff97723d9b7ade1c9c3cf48f770                        0.25
#
#                                   d5_towers_killed  d5_roshans_killed  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a                 0                  0
# b9c57c450ce74a2af79c9ce96fac144d                 0                  0
# 6db558535151ea18ca70a6892197db41                 0                  0
# 46a0ddce8f7ed2a8d9bd5edcbb925682                 0                  0
# b1b35ff97723d9b7ade1c9c3cf48f770                 0                  0
#
#                                   d5_obs_placed  d5_sen_placed
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a              0              0
# b9c57c450ce74a2af79c9ce96fac144d              0              0
# 6db558535151ea18ca70a6892197db41              0              0
# 46a0ddce8f7ed2a8d9bd5edcbb925682              2              0
# b1b35ff97723d9b7ade1c9c3cf48f770              0              0
#
# [5 rows x 245 columns]

# %% [markdown]
# Таблица `train_targets.csv` содержит информацию "из будущего" — то что неизвестно на момент, когда часы показывают `game_time`. Нас будет интересовать колонка `radiant_win` — в ней записано, победит команда Radiant или нет — это целевое событие, вероятность кооторого нужно оценивать. Для тестовой выборки такой информации нет.

# %% [markdown]
# ## Построение модели и оценка качества

# %% [markdown]
# #### Построим числовую матрицу объект-признак `X` и вектор ответов `y`

# %%
X = df_train_features.values
y = df_train_targets['radiant_win'].values

# %% [markdown]
# ## Работа с полными описаниями матчей
#
# Полные описания матчей ("сырые" данные) представлены в файлах `train_matches.jsonl` и `test_matches.jsonl`. Каждый файл содержит по одной строчке на матч — в строчке записан объект, закодированный в формате [JSON](https://en.wikipedia.org/wiki/JSON). Про JSON достаточно знать лишь то, что его можно лего переводить в Python-объекты (словари, спики, числа, строки и тд) при помощи функции `json.loads`.

# %% [markdown]
# ##### Посмотрим на одну строчку из файла

# %%
import json

with open('data_final/train_matches.jsonl') as fin:
    # Прочитаем 18-ю строчку из файла
    for i in range(18):
        line = fin.readline()
    
    # расшифруем формат JSON в обычный Python-объект
    match = json.loads(line)

# %% [markdown]
# Обект `match` — это большой словарь, в полях которого есть значения и другие вложенные словари. В частности есть массив `match['players']` в котором записано описание каждого игрока.
#
# Объект `match` — это и есть те данные, в том виде, в котором они встречаются в реальной жизни, на практике. Подробное описание полей есть в руководстве по задаче. Помните, что настоящий специалист по анализу данных может не вдаваться глубоко в предметную область (в данном контексте это означает что можно практически ничего не знать про игру Dota 2), для того чтобы найти сложную закономерность в данных; в этом искусство и сила специалистов по Data Science.

# %%
#match

# %% [markdown]
# #### Объекты с описанием игроков

# %%
player = match['players'][2]

# %% [markdown]
# KDA: число убийств, смертей и помощи союзникам

# %%
len(player['killed_by']), player['deaths'], player['assists']
# Out:
# (6, 11, 12)

# %% [markdown]
# Статистика по использованию умений игрока:

# %%
player['ability_uses']
# Out:
# {'kunkka_ghostship': 16,
#  'kunkka_return': 1,
#  'kunkka_torrent': 43,
#  'kunkka_x_marks_the_spot': 8}

# %% [markdown]
# #### Пример: временной ряд изменения золота во всем игрокам

# %% [markdown]
# #### Функция для чтения файла с матчами
#
# Далее приведена функция `read_matches(filename)`, которую можно использовать для чтения объектов из файлов с сырыми данными.
#
# Рекомендуется установить два Python пакета: `ujson` и `tqdm`, без них чтение будет работать дольше и не будет прогресс-бара.

# %%
import os

try:
    import ujson as json
except ModuleNotFoundError:
    import json
    print ('Установите пакет ujson для того чтобы декодировать JSON-объекты быстрее')
    
try:
    from tqdm import tqdm_notebook
except ModuleNotFoundError:
    tqdm_notebook = lambda x: x
    print ('Установите пакет tqdm для того чтобы видеть прогресс и оценку времени завершения')

def read_matches(matches_file):
    
    # Число матчей, нужно того чтобы видеть Progress Bar и оценку времени завершения
    MATCHES_COUNT = {
        'test_matches.jsonl': 10000,
        'train_matches.jsonl': 39675,
    }
    _, filename = os.path.split(matches_file)
    total_matches = MATCHES_COUNT.get(filename)
    
    with open(matches_file) as fin:
        for line in tqdm_notebook(fin, total=total_matches):
            yield json.loads(line)
# Out:
# Установите пакет ujson для того чтобы декодировать JSON-объекты быстрее

# %% [markdown]
# #### Чтение матчей в цикле
#
# Чтение всех матчей может занять 2-3 минуты. Поэтому очень важно во время хакатона следовать следующему алгоритму:
#
# 1. Прочитайте небольшое число матчей (10-100)
# 2. Напишите код, который извлекает из матча нужные признаки или считает нужную статистику
# 3. Убедитесь что код работает без ошибок
# 4. Запустите полный прогон вашего алгоритма по всем матчам
# 5. Сохраните результат в CSV-таблицу или при помощи `pickle`, для того чтобы его не пришлось вычислять заново

# %%
for match in read_matches('data_final/train_matches.jsonl'):
    match_id_hash = match['match_id_hash']
    game_time = match['game_time']
    
    # обработка матча
    
    for player in match['players']:
        pass  # обработка игрока
# Out:
# HBox(children=(IntProgress(value=0, max=39675), HTML(value='')))

# %% [markdown]
# ## Добавление новых признаков

# %%
import collections

PLAYER_FIELDS = [
    'hero_id',
    
    'kills',
    'deaths',
    'assists',
    'denies',
    'killed',
    'gold',
    'lh',
    'xp',
    'health',
    'max_health',
    'max_mana',
    'level',

    'x',
    'y',
    
    'stuns',
    'creeps_stacked',
    'camps_stacked',
    'rune_pickups',
    'firstblood_claimed',
    'teamfight_participation',
    'towers_killed',
    'roshans_killed',
    'obs_placed',
    'sen_placed',
]

def extract_features_csv(match):
    row = [
        ('match_id_hash', match['match_id_hash']),
    ]

    for slot, player in enumerate(match['players']):
        if slot < 5:
            player_name = 'r%d' % (slot + 1)
        else:
            player_name = 'd%d' % (slot - 4)

        for field in PLAYER_FIELDS:
            column_name = '%s_%s' % (player_name, field)
            row.append((column_name, player[field]))
            
    return collections.OrderedDict(row)

# %%
def add_new_features(df_features, matches_file):
    
    # Пройдем по сырым данным и добавим новые признаки в таблицу
    for match in read_matches(matches_file):
        match_id_hash = match['match_id_hash']

        # Подсчет числа разбитых Башен для обеих команд
        radiant_tower_kills = 0
        dire_tower_kills = 0
        diff_kills=0
        diff_level=0
        diff_max_health=0
        diff_damage=0
        diff_buyback_log=0
        diff_gold=0
        diff_assists =0
        diff_xp=0
        for objective in match['objectives']:
            if objective['type'] == 'CHAT_MESSAGE_TOWER_KILL':
                if objective['team'] == 2:
                    radiant_tower_kills += 1
                if objective['team'] == 3:
                    dire_tower_kills += 1
        for slot, player in enumerate(match['players']):
        if slot < 5:
            player_name = 'r%d' % (slot + 1)
        else:
            player_name = 'd%d' % (slot - 4)
       
    
        for i in range(5):
                player = match['players'][i]
                diff_kills += player['kills']
                diff_level += player['level']
                diff_max_health += player['max_health']
                diff_damage+= len(player['damage'])
                diff_buyback_log+= len(player['buyback_log'])
                diff_gold+=player['gold']
                diff_assists+=player['assists']
                diff_xp+=player['xp']
        for i in range(5,10):
                player = match['players'][i]
                diff_kills -= player['kills']
                diff_level -= player['level']
                diff_max_health -= player['max_health']
                diff_damage-= len(player['damage'])
                diff_buyback_log-= len(player['buyback_log'])
                diff_gold-=player['gold']
                diff_assists-=player['assists']
                diff_xp-=player['xp']
            
        
        
        # Записываем в таблицу значения признаков
        df_features.loc[match_id_hash, 'diff_kills'] = diff_kills
        df_features.loc[match_id_hash, 'diff_level'] = diff_level
        df_features.loc[match_id_hash, 'diff_max_health'] = diff_max_health
        df_features.loc[match_id_hash, 'diff_damage'] = diff_damage
        df_features.loc[match_id_hash, 'diff_buyback_log'] = diff_buyback_log
        df_features.loc[match_id_hash, 'diff_assists'] = diff_assists
        df_features.loc[match_id_hash, 'diff_xp'] = diff_xp
        df_features.loc[match_id_hash, 'diff_gold'] = diff_gold
        
        # ... здесь вы можете дописать свои собственные признаки ...

# %%
# Скопируем таблицу с признаками
df_train_features_extended = df_train_features.copy()

# Добавим новые признаки
add_new_features(df_train_features_extended, 'data_final/train_matches.jsonl')
# Out:
# HBox(children=(IntProgress(value=0, max=39675), HTML(value='')))

# %% [markdown]
# В последних колонках видим новые признаки

# %%
df_train_features_extended.head()
# Out:
#                                   game_time  game_mode  lobby_type  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a        155         22           7
# b9c57c450ce74a2af79c9ce96fac144d        658          4           0
# 6db558535151ea18ca70a6892197db41         21         23           0
# 46a0ddce8f7ed2a8d9bd5edcbb925682        576         22           7
# b1b35ff97723d9b7ade1c9c3cf48f770        453         22           7
#
#                                   objectives_len  chat_len  r1_hero_id  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a               1        11          11
# b9c57c450ce74a2af79c9ce96fac144d               3        10          15
# 6db558535151ea18ca70a6892197db41               0         0         101
# 46a0ddce8f7ed2a8d9bd5edcbb925682               1         4          14
# b1b35ff97723d9b7ade1c9c3cf48f770               1         3          42
#
#                                   r1_kills  r1_deaths  r1_assists  r1_denies  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a         0          0           0          0
# b9c57c450ce74a2af79c9ce96fac144d         7          2           0          7
# 6db558535151ea18ca70a6892197db41         0          0           0          0
# 46a0ddce8f7ed2a8d9bd5edcbb925682         1          0           3          1
# b1b35ff97723d9b7ade1c9c3cf48f770         0          1           1          0
#
#                                     ...      d5_obs_placed  d5_sen_placed  \
# match_id_hash                       ...
# a400b8f29dece5f4d266f49f1ae2e98a    ...                  0              0
# b9c57c450ce74a2af79c9ce96fac144d    ...                  0              0
# 6db558535151ea18ca70a6892197db41    ...                  0              0
# 46a0ddce8f7ed2a8d9bd5edcbb925682    ...                  2              0
# b1b35ff97723d9b7ade1c9c3cf48f770    ...                  0              0
#
#                                   diff_kills  diff_level  diff_max_health  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a        -1.0        -4.0              0.0
# b9c57c450ce74a2af79c9ce96fac144d        13.0         7.0            680.0
# 6db558535151ea18ca70a6892197db41         0.0         0.0            -20.0
# 46a0ddce8f7ed2a8d9bd5edcbb925682         5.0         4.0            -80.0
# b1b35ff97723d9b7ade1c9c3cf48f770        -2.0        -1.0            760.0
#
#                                   diff_damage  diff_buyback_log  diff_assists  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a          2.0               0.0          -1.0
# b9c57c450ce74a2af79c9ce96fac144d         -4.0              -1.0          11.0
# 6db558535151ea18ca70a6892197db41          0.0               0.0           0.0
# 46a0ddce8f7ed2a8d9bd5edcbb925682        -19.0               0.0           7.0
# b1b35ff97723d9b7ade1c9c3cf48f770        -16.0               0.0           1.0
#
#                                   diff_xp  diff_gold
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a  -1093.0    -1911.0
# b9c57c450ce74a2af79c9ce96fac144d   4641.0     5028.0
# 6db558535151ea18ca70a6892197db41      0.0      400.0
# 46a0ddce8f7ed2a8d9bd5edcbb925682   2820.0     2047.0
# b1b35ff97723d9b7ade1c9c3cf48f770  -1044.0    -1098.0
#
# [5 rows x 253 columns]

# %% [markdown]
# #### Оценка улучшения качества
#
# Запустим кросс-валидацию и сравним одну и ту же модель на разных признаковых описаниях:
#
# 1. от организаторов (base)
# 2. с добавлением тех что мы только что построили (extended)

# %%
# %%time
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
import catboost as cb
from sklearn.model_selection import train_test_split
from sklearn.model_selection import ShuffleSplit, KFold

X_train, X_valid, y_train, y_valid = train_test_split(df_train_features_extended, y, test_size=0.3, random_state=42)

#clf = cb.CatBoostClassifier()#logging_level='Silent',iterations=1000, bootstrap_type='Bayesian',depth=6
#clf.fit(X_train,y_train)
#model=clf

#print((clf.predict(X_valid)>0.5==y_valid).mean())
#model=cb.CatBoostClassifier(iterations=1600, bootstrap_type='Bayesian',depth=7,logging_level='Silent')
#model = RandomForestClassifier(random_state=42)

#from sklearn.model_selection import ShuffleSplit, KFold
from sklearn.ensemble import RandomForestClassifier

model = cb.CatBoostClassifier()
model.fit(X_train, y_train)
# Создаем 5 разбиений в соотношении — обучение 70% / валидация 30%
cv = ShuffleSplit(n_splits=5, test_size=0.3, random_state=123)

cv_scores_extended = cross_val_score(model, df_train_features_extended.values, y, cv=cv, scoring='roc_auc', n_jobs=-1)
# Out:
# 0:	learn: 0.6834829	total: 299ms	remaining: 4m 58s
# 1:	learn: 0.6731289	total: 550ms	remaining: 4m 34s
# 2:	learn: 0.6642935	total: 795ms	remaining: 4m 24s
# 3:	learn: 0.6555236	total: 1.05s	remaining: 4m 20s
# 4:	learn: 0.6474687	total: 1.32s	remaining: 4m 22s
# 5:	learn: 0.6396884	total: 1.57s	remaining: 4m 20s
# 6:	learn: 0.6328054	total: 1.83s	remaining: 4m 19s
# 7:	learn: 0.6260353	total: 2.04s	remaining: 4m 13s
# 8:	learn: 0.6200339	total: 2.29s	remaining: 4m 12s
# 9:	learn: 0.6140823	total: 2.54s	remaining: 4m 11s
# 10:	learn: 0.6089234	total: 2.8s	remaining: 4m 11s
# 11:	learn: 0.6049011	total: 3.06s	remaining: 4m 11s
# 12:	learn: 0.6003666	total: 3.34s	remaining: 4m 13s
# 13:	learn: 0.5962620	total: 3.6s	remaining: 4m 13s
# 14:	learn: 0.5924308	total: 3.88s	remaining: 4m 14s
# 15:	learn: 0.5885531	total: 4.21s	remaining: 4m 18s
# 16:	learn: 0.5854015	total: 4.52s	remaining: 4m 21s
# 17:	learn: 0.5816187	total: 4.79s	remaining: 4m 21s
# 18:	learn: 0.5782542	total: 5.09s	remaining: 4m 22s
# 19:	learn: 0.5755669	total: 5.49s	remaining: 4m 29s
# 20:	learn: 0.5727832	total: 5.78s	remaining: 4m 29s
# 21:	learn: 0.5698010	total: 6.2s	remaining: 4m 35s
# 22:	learn: 0.5668472	total: 6.5s	remaining: 4m 36s
# 23:	learn: 0.5638090	total: 6.95s	remaining: 4m 42s
# 24:	learn: 0.5612602	total: 7.31s	remaining: 4m 45s
# 25:	learn: 0.5589743	total: 7.61s	remaining: 4m 45s
# 26:	learn: 0.5566670	total: 7.9s	remaining: 4m 44s
# 27:	learn: 0.5547286	total: 8.18s	remaining: 4m 44s
# 28:	learn: 0.5524452	total: 8.47s	remaining: 4m 43s
# 29:	learn: 0.5505211	total: 8.73s	remaining: 4m 42s
# 30:	learn: 0.5485137	total: 9s	remaining: 4m 41s
# 31:	learn: 0.5467103	total: 9.26s	remaining: 4m 40s
# 32:	learn: 0.5455069	total: 9.56s	remaining: 4m 40s
# 33:	learn: 0.5440268	total: 9.85s	remaining: 4m 39s
# 34:	learn: 0.5425248	total: 10.1s	remaining: 4m 39s
# 35:	learn: 0.5410972	total: 10.4s	remaining: 4m 39s
# 36:	learn: 0.5396950	total: 10.7s	remaining: 4m 38s
# 37:	learn: 0.5383633	total: 11s	remaining: 4m 38s
# 38:	learn: 0.5374073	total: 11.3s	remaining: 4m 37s
# 39:	learn: 0.5366486	total: 11.5s	remaining: 4m 36s
# 40:	learn: 0.5356045	total: 11.8s	remaining: 4m 36s
# 41:	learn: 0.5348313	total: 12.1s	remaining: 4m 35s
# 42:	learn: 0.5339831	total: 12.3s	remaining: 4m 34s
# 43:	learn: 0.5331434	total: 12.6s	remaining: 4m 34s
# 44:	learn: 0.5323745	total: 12.9s	remaining: 4m 33s
# 45:	learn: 0.5317517	total: 13.2s	remaining: 4m 32s
# 46:	learn: 0.5310196	total: 13.4s	remaining: 4m 32s
# 47:	learn: 0.5301736	total: 13.7s	remaining: 4m 32s
# 48:	learn: 0.5293773	total: 14s	remaining: 4m 31s
# 49:	learn: 0.5285643	total: 14.3s	remaining: 4m 31s
# 50:	learn: 0.5279106	total: 14.6s	remaining: 4m 31s
# 51:	learn: 0.5272823	total: 14.9s	remaining: 4m 30s
# 52:	learn: 0.5263993	total: 15.1s	remaining: 4m 30s
# 53:	learn: 0.5258364	total: 15.4s	remaining: 4m 29s
# 54:	learn: 0.5251847	total: 15.8s	remaining: 4m 31s
# 55:	learn: 0.5246118	total: 16.1s	remaining: 4m 31s
# 56:	learn: 0.5240634	total: 16.4s	remaining: 4m 30s
# 57:	learn: 0.5236227	total: 16.6s	remaining: 4m 30s
# 58:	learn: 0.5230846	total: 16.9s	remaining: 4m 29s
# 59:	learn: 0.5227073	total: 17.1s	remaining: 4m 28s
# 60:	learn: 0.5223479	total: 17.3s	remaining: 4m 26s
# 61:	learn: 0.5220844	total: 17.7s	remaining: 4m 27s
# 62:	learn: 0.5216024	total: 17.9s	remaining: 4m 26s
# 63:	learn: 0.5210955	total: 18.3s	remaining: 4m 28s
# 64:	learn: 0.5207437	total: 18.6s	remaining: 4m 27s
# 65:	learn: 0.5205177	total: 18.9s	remaining: 4m 27s
# 66:	learn: 0.5200398	total: 19.2s	remaining: 4m 27s
# 67:	learn: 0.5197664	total: 19.5s	remaining: 4m 27s
# 68:	learn: 0.5193835	total: 19.8s	remaining: 4m 26s
# 69:	learn: 0.5189849	total: 20s	remaining: 4m 26s
# 70:	learn: 0.5186370	total: 20.3s	remaining: 4m 25s
# 71:	learn: 0.5182599	total: 20.6s	remaining: 4m 24s
# 72:	learn: 0.5180525	total: 20.8s	remaining: 4m 24s
# 73:	learn: 0.5175961	total: 21.1s	remaining: 4m 23s
# 74:	learn: 0.5171212	total: 21.4s	remaining: 4m 23s
# 75:	learn: 0.5167844	total: 21.6s	remaining: 4m 22s
# 76:	learn: 0.5164469	total: 21.9s	remaining: 4m 22s
# 77:	learn: 0.5162814	total: 22.1s	remaining: 4m 21s
# 78:	learn: 0.5160165	total: 22.3s	remaining: 4m 20s
# 79:	learn: 0.5157132	total: 22.6s	remaining: 4m 19s
# 80:	learn: 0.5154428	total: 22.8s	remaining: 4m 19s
# 81:	learn: 0.5152132	total: 23.1s	remaining: 4m 18s
# 82:	learn: 0.5149633	total: 23.3s	remaining: 4m 17s
# 83:	learn: 0.5146396	total: 23.5s	remaining: 4m 16s
# 84:	learn: 0.5143444	total: 23.8s	remaining: 4m 15s
# 85:	learn: 0.5141444	total: 24s	remaining: 4m 15s
# 86:	learn: 0.5139651	total: 24.2s	remaining: 4m 14s
# 87:	learn: 0.5137370	total: 24.5s	remaining: 4m 13s
# 88:	learn: 0.5135349	total: 24.7s	remaining: 4m 13s
# 89:	learn: 0.5134216	total: 25s	remaining: 4m 12s
# 90:	learn: 0.5131801	total: 25.2s	remaining: 4m 11s
# 91:	learn: 0.5129565	total: 25.4s	remaining: 4m 11s
# 92:	learn: 0.5128501	total: 25.7s	remaining: 4m 10s
# 93:	learn: 0.5126420	total: 25.9s	remaining: 4m 9s
# 94:	learn: 0.5124436	total: 26.1s	remaining: 4m 8s
# 95:	learn: 0.5122683	total: 26.4s	remaining: 4m 8s
# 96:	learn: 0.5120356	total: 26.6s	remaining: 4m 7s
# 97:	learn: 0.5118031	total: 26.9s	remaining: 4m 7s
# 98:	learn: 0.5116941	total: 27.1s	remaining: 4m 6s
# 99:	learn: 0.5115154	total: 27.3s	remaining: 4m 6s
# 100:	learn: 0.5114040	total: 27.6s	remaining: 4m 5s
# 101:	learn: 0.5111872	total: 27.8s	remaining: 4m 5s
# 102:	learn: 0.5110049	total: 28.1s	remaining: 4m 4s
# 103:	learn: 0.5108528	total: 28.3s	remaining: 4m 4s
# 104:	learn: 0.5106865	total: 28.6s	remaining: 4m 3s
# 105:	learn: 0.5104772	total: 28.8s	remaining: 4m 3s
# 106:	learn: 0.5103204	total: 29.1s	remaining: 4m 2s
# 107:	learn: 0.5100693	total: 29.3s	remaining: 4m 2s
# 108:	learn: 0.5098778	total: 29.6s	remaining: 4m 1s
# 109:	learn: 0.5096670	total: 29.8s	remaining: 4m 1s
# 110:	learn: 0.5095604	total: 30s	remaining: 4m
# 111:	learn: 0.5094143	total: 30.3s	remaining: 4m
# 112:	learn: 0.5092640	total: 30.5s	remaining: 3m 59s
# 113:	learn: 0.5091596	total: 30.8s	remaining: 3m 59s
# 114:	learn: 0.5089444	total: 31s	remaining: 3m 58s
# 115:	learn: 0.5088643	total: 31.3s	remaining: 3m 58s
# 116:	learn: 0.5087360	total: 31.5s	remaining: 3m 57s
# 117:	learn: 0.5086228	total: 31.7s	remaining: 3m 57s
# 118:	learn: 0.5085097	total: 32s	remaining: 3m 56s
# 119:	learn: 0.5083749	total: 32.2s	remaining: 3m 56s
# 120:	learn: 0.5082851	total: 32.4s	remaining: 3m 55s
# 121:	learn: 0.5081655	total: 32.7s	remaining: 3m 55s
# 122:	learn: 0.5080403	total: 33s	remaining: 3m 55s
# 123:	learn: 0.5078875	total: 33.3s	remaining: 3m 54s
# 124:	learn: 0.5077699	total: 33.5s	remaining: 3m 54s
# 125:	learn: 0.5076933	total: 33.8s	remaining: 3m 54s
# 126:	learn: 0.5075852	total: 34.1s	remaining: 3m 54s
# 127:	learn: 0.5075159	total: 34.4s	remaining: 3m 54s
# 128:	learn: 0.5073645	total: 34.7s	remaining: 3m 54s
# 129:	learn: 0.5071794	total: 35s	remaining: 3m 54s
# 130:	learn: 0.5070970	total: 35.3s	remaining: 3m 54s
# 131:	learn: 0.5070019	total: 35.6s	remaining: 3m 54s
# 132:	learn: 0.5069404	total: 35.9s	remaining: 3m 54s
# 133:	learn: 0.5067263	total: 36.2s	remaining: 3m 53s
# 134:	learn: 0.5065657	total: 36.4s	remaining: 3m 53s
# 135:	learn: 0.5064188	total: 36.7s	remaining: 3m 53s
# 136:	learn: 0.5063393	total: 37s	remaining: 3m 53s
# 137:	learn: 0.5062260	total: 37.3s	remaining: 3m 52s
# 138:	learn: 0.5061254	total: 37.5s	remaining: 3m 52s
# 139:	learn: 0.5059984	total: 37.8s	remaining: 3m 52s
# 140:	learn: 0.5059004	total: 38.1s	remaining: 3m 52s
# 141:	learn: 0.5057443	total: 38.4s	remaining: 3m 51s
# 142:	learn: 0.5055945	total: 38.6s	remaining: 3m 51s
# 143:	learn: 0.5054579	total: 39s	remaining: 3m 51s
# 144:	learn: 0.5052918	total: 39.3s	remaining: 3m 51s
# 145:	learn: 0.5052116	total: 39.5s	remaining: 3m 51s
# 146:	learn: 0.5050787	total: 39.8s	remaining: 3m 51s
# 147:	learn: 0.5049385	total: 40.1s	remaining: 3m 50s
# 148:	learn: 0.5048413	total: 40.4s	remaining: 3m 50s
# 149:	learn: 0.5047206	total: 40.7s	remaining: 3m 50s
# 150:	learn: 0.5046301	total: 41s	remaining: 3m 50s
# 151:	learn: 0.5045178	total: 41.2s	remaining: 3m 50s
# 152:	learn: 0.5044268	total: 41.5s	remaining: 3m 49s
# 153:	learn: 0.5042862	total: 41.8s	remaining: 3m 49s
# 154:	learn: 0.5042056	total: 42s	remaining: 3m 49s
# 155:	learn: 0.5040895	total: 42.3s	remaining: 3m 48s
# 156:	learn: 0.5039946	total: 42.5s	remaining: 3m 48s
# 157:	learn: 0.5039086	total: 42.7s	remaining: 3m 47s
# 158:	learn: 0.5038089	total: 43s	remaining: 3m 47s
# 159:	learn: 0.5036920	total: 43.2s	remaining: 3m 46s
# 160:	learn: 0.5035301	total: 43.4s	remaining: 3m 46s
# 161:	learn: 0.5034581	total: 43.7s	remaining: 3m 46s
# 162:	learn: 0.5033373	total: 44s	remaining: 3m 45s
# 163:	learn: 0.5032119	total: 44.2s	remaining: 3m 45s
# 164:	learn: 0.5031190	total: 44.5s	remaining: 3m 45s
# 165:	learn: 0.5030424	total: 44.8s	remaining: 3m 45s
# 166:	learn: 0.5029727	total: 45.1s	remaining: 3m 45s
# 167:	learn: 0.5028171	total: 45.4s	remaining: 3m 44s
# 168:	learn: 0.5027330	total: 45.7s	remaining: 3m 44s
# 169:	learn: 0.5026859	total: 46s	remaining: 3m 44s
# 170:	learn: 0.5025856	total: 46.3s	remaining: 3m 44s
# 171:	learn: 0.5025349	total: 46.6s	remaining: 3m 44s
# 172:	learn: 0.5024566	total: 46.9s	remaining: 3m 43s
# 173:	learn: 0.5023310	total: 47.1s	remaining: 3m 43s
# 174:	learn: 0.5022642	total: 47.4s	remaining: 3m 43s
# 175:	learn: 0.5021604	total: 47.7s	remaining: 3m 43s
# 176:	learn: 0.5020517	total: 48s	remaining: 3m 42s
# 177:	learn: 0.5020068	total: 48.2s	remaining: 3m 42s
# 178:	learn: 0.5019033	total: 48.5s	remaining: 3m 42s
# 179:	learn: 0.5018422	total: 48.8s	remaining: 3m 42s
# 180:	learn: 0.5017209	total: 49.1s	remaining: 3m 42s
# 181:	learn: 0.5016427	total: 49.4s	remaining: 3m 42s
# 182:	learn: 0.5015468	total: 49.7s	remaining: 3m 41s
# 183:	learn: 0.5014410	total: 50s	remaining: 3m 41s
# 184:	learn: 0.5013497	total: 50.3s	remaining: 3m 41s
# 185:	learn: 0.5012211	total: 50.5s	remaining: 3m 41s
# 186:	learn: 0.5010984	total: 50.8s	remaining: 3m 40s
# 187:	learn: 0.5010307	total: 51.1s	remaining: 3m 40s
# 188:	learn: 0.5009412	total: 51.4s	remaining: 3m 40s
# 189:	learn: 0.5008330	total: 51.6s	remaining: 3m 40s
# 190:	learn: 0.5007547	total: 51.9s	remaining: 3m 39s
# 191:	learn: 0.5006901	total: 52.1s	remaining: 3m 39s
# 192:	learn: 0.5005608	total: 52.4s	remaining: 3m 39s
# 193:	learn: 0.5004758	total: 52.6s	remaining: 3m 38s
# 194:	learn: 0.5003257	total: 52.9s	remaining: 3m 38s
# 195:	learn: 0.5002791	total: 53.1s	remaining: 3m 37s
# 196:	learn: 0.5001903	total: 53.3s	remaining: 3m 37s
# 197:	learn: 0.5001095	total: 53.6s	remaining: 3m 37s
# 198:	learn: 0.5000079	total: 53.8s	remaining: 3m 36s
# 199:	learn: 0.4999675	total: 54s	remaining: 3m 36s
# 200:	learn: 0.4998920	total: 54.3s	remaining: 3m 35s
# 201:	learn: 0.4997774	total: 54.5s	remaining: 3m 35s
# 202:	learn: 0.4997049	total: 54.7s	remaining: 3m 34s
# 203:	learn: 0.4996259	total: 55s	remaining: 3m 34s
# 204:	learn: 0.4995094	total: 55.3s	remaining: 3m 34s
# 205:	learn: 0.4994269	total: 55.6s	remaining: 3m 34s
# 206:	learn: 0.4993412	total: 55.9s	remaining: 3m 34s
# 207:	learn: 0.4992545	total: 56.2s	remaining: 3m 34s
# 208:	learn: 0.4991765	total: 56.5s	remaining: 3m 33s
# 209:	learn: 0.4990532	total: 56.7s	remaining: 3m 33s
# 210:	learn: 0.4989696	total: 57s	remaining: 3m 33s
# 211:	learn: 0.4988551	total: 57.3s	remaining: 3m 32s
# 212:	learn: 0.4987921	total: 57.5s	remaining: 3m 32s
# 213:	learn: 0.4987559	total: 57.8s	remaining: 3m 32s
# 214:	learn: 0.4986836	total: 58s	remaining: 3m 31s
# 215:	learn: 0.4985785	total: 58.2s	remaining: 3m 31s
# 216:	learn: 0.4984670	total: 58.5s	remaining: 3m 30s
# 217:	learn: 0.4983687	total: 58.7s	remaining: 3m 30s
# 218:	learn: 0.4982866	total: 58.9s	remaining: 3m 30s
# 219:	learn: 0.4981243	total: 59.2s	remaining: 3m 29s
# 220:	learn: 0.4980216	total: 59.4s	remaining: 3m 29s
# 221:	learn: 0.4979212	total: 59.7s	remaining: 3m 29s
# 222:	learn: 0.4978665	total: 59.9s	remaining: 3m 28s
# 223:	learn: 0.4978052	total: 1m	remaining: 3m 28s
# 224:	learn: 0.4976993	total: 1m	remaining: 3m 27s
# 225:	learn: 0.4976153	total: 1m	remaining: 3m 27s
# 226:	learn: 0.4975499	total: 1m	remaining: 3m 27s
# 227:	learn: 0.4974523	total: 1m 1s	remaining: 3m 26s
# 228:	learn: 0.4973821	total: 1m 1s	remaining: 3m 26s
# 229:	learn: 0.4973405	total: 1m 1s	remaining: 3m 26s
# 230:	learn: 0.4972490	total: 1m 1s	remaining: 3m 25s
# 231:	learn: 0.4971764	total: 1m 2s	remaining: 3m 25s
# 232:	learn: 0.4970822	total: 1m 2s	remaining: 3m 24s
# 233:	learn: 0.4969988	total: 1m 2s	remaining: 3m 24s
# 234:	learn: 0.4969259	total: 1m 2s	remaining: 3m 24s
# 235:	learn: 0.4968230	total: 1m 2s	remaining: 3m 23s
# 236:	learn: 0.4967083	total: 1m 3s	remaining: 3m 23s
# 237:	learn: 0.4965590	total: 1m 3s	remaining: 3m 23s
# 238:	learn: 0.4964672	total: 1m 3s	remaining: 3m 23s
# 239:	learn: 0.4963802	total: 1m 4s	remaining: 3m 23s
# 240:	learn: 0.4962996	total: 1m 4s	remaining: 3m 23s
# 241:	learn: 0.4961865	total: 1m 4s	remaining: 3m 23s
# 242:	learn: 0.4961137	total: 1m 5s	remaining: 3m 23s
# 243:	learn: 0.4960392	total: 1m 5s	remaining: 3m 22s
# 244:	learn: 0.4959446	total: 1m 5s	remaining: 3m 22s
# 245:	learn: 0.4958480	total: 1m 6s	remaining: 3m 22s
# 246:	learn: 0.4957509	total: 1m 6s	remaining: 3m 22s
# 247:	learn: 0.4956820	total: 1m 6s	remaining: 3m 22s
# 248:	learn: 0.4956305	total: 1m 6s	remaining: 3m 21s
# 249:	learn: 0.4955421	total: 1m 7s	remaining: 3m 21s
# 250:	learn: 0.4954357	total: 1m 7s	remaining: 3m 21s
# 251:	learn: 0.4953814	total: 1m 7s	remaining: 3m 21s
# 252:	learn: 0.4952837	total: 1m 8s	remaining: 3m 20s
# 253:	learn: 0.4952333	total: 1m 8s	remaining: 3m 20s
# 254:	learn: 0.4951551	total: 1m 8s	remaining: 3m 20s
# 255:	learn: 0.4950834	total: 1m 8s	remaining: 3m 20s
# 256:	learn: 0.4950294	total: 1m 9s	remaining: 3m 20s
# 257:	learn: 0.4949129	total: 1m 9s	remaining: 3m 20s
# 258:	learn: 0.4948556	total: 1m 9s	remaining: 3m 19s
# 259:	learn: 0.4947343	total: 1m 10s	remaining: 3m 19s
# 260:	learn: 0.4946385	total: 1m 10s	remaining: 3m 19s
# 261:	learn: 0.4945431	total: 1m 10s	remaining: 3m 18s
# 262:	learn: 0.4944306	total: 1m 10s	remaining: 3m 18s
# 263:	learn: 0.4943732	total: 1m 11s	remaining: 3m 18s
# 264:	learn: 0.4943304	total: 1m 11s	remaining: 3m 18s
# 265:	learn: 0.4942521	total: 1m 11s	remaining: 3m 17s
# 266:	learn: 0.4941658	total: 1m 11s	remaining: 3m 17s
# 267:	learn: 0.4940939	total: 1m 12s	remaining: 3m 17s
# 268:	learn: 0.4940276	total: 1m 12s	remaining: 3m 16s
# 269:	learn: 0.4939342	total: 1m 12s	remaining: 3m 16s
# 270:	learn: 0.4938817	total: 1m 12s	remaining: 3m 16s
# 271:	learn: 0.4937580	total: 1m 13s	remaining: 3m 15s
# 272:	learn: 0.4936710	total: 1m 13s	remaining: 3m 15s
# 273:	learn: 0.4935598	total: 1m 13s	remaining: 3m 15s
# 274:	learn: 0.4934967	total: 1m 13s	remaining: 3m 14s
# 275:	learn: 0.4934168	total: 1m 14s	remaining: 3m 14s
# 276:	learn: 0.4933007	total: 1m 14s	remaining: 3m 14s
# 277:	learn: 0.4932187	total: 1m 14s	remaining: 3m 14s
# 278:	learn: 0.4931377	total: 1m 15s	remaining: 3m 14s
# 279:	learn: 0.4930612	total: 1m 15s	remaining: 3m 13s
# 280:	learn: 0.4929941	total: 1m 15s	remaining: 3m 13s
# 281:	learn: 0.4929061	total: 1m 15s	remaining: 3m 13s
# 282:	learn: 0.4928044	total: 1m 16s	remaining: 3m 13s
# 283:	learn: 0.4927591	total: 1m 16s	remaining: 3m 12s
# 284:	learn: 0.4926366	total: 1m 16s	remaining: 3m 12s
# 285:	learn: 0.4925510	total: 1m 17s	remaining: 3m 12s
# 286:	learn: 0.4924937	total: 1m 17s	remaining: 3m 12s
# 287:	learn: 0.4923342	total: 1m 17s	remaining: 3m 11s
# 288:	learn: 0.4922738	total: 1m 17s	remaining: 3m 11s
# 289:	learn: 0.4921947	total: 1m 18s	remaining: 3m 11s
# 290:	learn: 0.4920684	total: 1m 18s	remaining: 3m 11s
# 291:	learn: 0.4920074	total: 1m 18s	remaining: 3m 10s
# 292:	learn: 0.4919327	total: 1m 18s	remaining: 3m 10s
# 293:	learn: 0.4918878	total: 1m 19s	remaining: 3m 10s
# 294:	learn: 0.4918045	total: 1m 19s	remaining: 3m 9s
# 295:	learn: 0.4917130	total: 1m 19s	remaining: 3m 9s
# 296:	learn: 0.4916272	total: 1m 20s	remaining: 3m 9s
# 297:	learn: 0.4915548	total: 1m 20s	remaining: 3m 9s
# 298:	learn: 0.4915094	total: 1m 20s	remaining: 3m 8s
# 299:	learn: 0.4914224	total: 1m 20s	remaining: 3m 8s
# 300:	learn: 0.4913401	total: 1m 21s	remaining: 3m 8s
# 301:	learn: 0.4912587	total: 1m 21s	remaining: 3m 8s
# 302:	learn: 0.4911855	total: 1m 21s	remaining: 3m 8s
# 303:	learn: 0.4911098	total: 1m 22s	remaining: 3m 7s
# 304:	learn: 0.4910501	total: 1m 22s	remaining: 3m 7s
# 305:	learn: 0.4909850	total: 1m 22s	remaining: 3m 7s
# 306:	learn: 0.4909381	total: 1m 22s	remaining: 3m 7s
# 307:	learn: 0.4908381	total: 1m 23s	remaining: 3m 6s
# 308:	learn: 0.4907548	total: 1m 23s	remaining: 3m 6s
# 309:	learn: 0.4906848	total: 1m 23s	remaining: 3m 6s
# 310:	learn: 0.4906044	total: 1m 24s	remaining: 3m 6s
# 311:	learn: 0.4905224	total: 1m 24s	remaining: 3m 5s
# 312:	learn: 0.4904082	total: 1m 24s	remaining: 3m 5s
# 313:	learn: 0.4903334	total: 1m 24s	remaining: 3m 5s
# 314:	learn: 0.4902185	total: 1m 25s	remaining: 3m 4s
# 315:	learn: 0.4901196	total: 1m 25s	remaining: 3m 4s
# 316:	learn: 0.4900217	total: 1m 25s	remaining: 3m 4s
# 317:	learn: 0.4899394	total: 1m 25s	remaining: 3m 3s
# 318:	learn: 0.4898907	total: 1m 25s	remaining: 3m 3s
# 319:	learn: 0.4898350	total: 1m 26s	remaining: 3m 3s
# 320:	learn: 0.4897691	total: 1m 26s	remaining: 3m 2s
# 321:	learn: 0.4896782	total: 1m 26s	remaining: 3m 2s
# 322:	learn: 0.4896375	total: 1m 26s	remaining: 3m 2s
# 323:	learn: 0.4895742	total: 1m 27s	remaining: 3m 2s
# 324:	learn: 0.4895157	total: 1m 27s	remaining: 3m 1s
# 325:	learn: 0.4894347	total: 1m 27s	remaining: 3m 1s
# 326:	learn: 0.4893763	total: 1m 28s	remaining: 3m 1s
# 327:	learn: 0.4892808	total: 1m 28s	remaining: 3m
# 328:	learn: 0.4891774	total: 1m 28s	remaining: 3m
# 329:	learn: 0.4891113	total: 1m 28s	remaining: 3m
# 330:	learn: 0.4890426	total: 1m 29s	remaining: 3m
# 331:	learn: 0.4889498	total: 1m 29s	remaining: 2m 59s
# 332:	learn: 0.4888335	total: 1m 29s	remaining: 2m 59s
# 333:	learn: 0.4887804	total: 1m 29s	remaining: 2m 59s
# 334:	learn: 0.4886887	total: 1m 30s	remaining: 2m 58s
# 335:	learn: 0.4886218	total: 1m 30s	remaining: 2m 58s
# 336:	learn: 0.4885155	total: 1m 30s	remaining: 2m 57s
# 337:	learn: 0.4884470	total: 1m 30s	remaining: 2m 57s
# 338:	learn: 0.4883464	total: 1m 30s	remaining: 2m 57s
# 339:	learn: 0.4882211	total: 1m 31s	remaining: 2m 56s
# 340:	learn: 0.4881702	total: 1m 31s	remaining: 2m 56s
# 341:	learn: 0.4881159	total: 1m 31s	remaining: 2m 56s
# 342:	learn: 0.4880475	total: 1m 31s	remaining: 2m 55s
# 343:	learn: 0.4879611	total: 1m 32s	remaining: 2m 55s
# 344:	learn: 0.4878948	total: 1m 32s	remaining: 2m 55s
# 345:	learn: 0.4878426	total: 1m 32s	remaining: 2m 54s
# 346:	learn: 0.4877410	total: 1m 32s	remaining: 2m 54s
# 347:	learn: 0.4876785	total: 1m 33s	remaining: 2m 54s
# 348:	learn: 0.4876243	total: 1m 33s	remaining: 2m 53s
# 349:	learn: 0.4875546	total: 1m 33s	remaining: 2m 53s
# 350:	learn: 0.4874853	total: 1m 33s	remaining: 2m 53s
# 351:	learn: 0.4873867	total: 1m 33s	remaining: 2m 52s
# 352:	learn: 0.4873282	total: 1m 34s	remaining: 2m 52s
# 353:	learn: 0.4872293	total: 1m 34s	remaining: 2m 52s
# 354:	learn: 0.4871045	total: 1m 34s	remaining: 2m 51s
# 355:	learn: 0.4870279	total: 1m 34s	remaining: 2m 51s
# 356:	learn: 0.4869422	total: 1m 35s	remaining: 2m 51s
# 357:	learn: 0.4868772	total: 1m 35s	remaining: 2m 51s
# 358:	learn: 0.4867951	total: 1m 35s	remaining: 2m 50s
# 359:	learn: 0.4867104	total: 1m 35s	remaining: 2m 50s
# 360:	learn: 0.4865976	total: 1m 36s	remaining: 2m 50s
# 361:	learn: 0.4865476	total: 1m 36s	remaining: 2m 50s
# 362:	learn: 0.4864589	total: 1m 36s	remaining: 2m 50s
# 363:	learn: 0.4863621	total: 1m 37s	remaining: 2m 49s
# 364:	learn: 0.4862452	total: 1m 37s	remaining: 2m 49s
# 365:	learn: 0.4861826	total: 1m 37s	remaining: 2m 49s
# 366:	learn: 0.4860870	total: 1m 38s	remaining: 2m 49s
# 367:	learn: 0.4859648	total: 1m 38s	remaining: 2m 48s
# 368:	learn: 0.4858802	total: 1m 38s	remaining: 2m 48s
# 369:	learn: 0.4858187	total: 1m 38s	remaining: 2m 48s
# 370:	learn: 0.4857177	total: 1m 39s	remaining: 2m 48s
# 371:	learn: 0.4856353	total: 1m 39s	remaining: 2m 47s
# 372:	learn: 0.4855556	total: 1m 39s	remaining: 2m 47s
# 373:	learn: 0.4854547	total: 1m 40s	remaining: 2m 47s
# 374:	learn: 0.4853747	total: 1m 40s	remaining: 2m 47s
# 375:	learn: 0.4852691	total: 1m 40s	remaining: 2m 47s
# 376:	learn: 0.4851750	total: 1m 41s	remaining: 2m 47s
# 377:	learn: 0.4850485	total: 1m 41s	remaining: 2m 47s
# 378:	learn: 0.4849617	total: 1m 41s	remaining: 2m 47s
# 379:	learn: 0.4848336	total: 1m 42s	remaining: 2m 46s
# 380:	learn: 0.4847357	total: 1m 42s	remaining: 2m 47s
# 381:	learn: 0.4846415	total: 1m 43s	remaining: 2m 46s
# 382:	learn: 0.4845285	total: 1m 43s	remaining: 2m 46s
# 383:	learn: 0.4844057	total: 1m 43s	remaining: 2m 46s
# 384:	learn: 0.4843078	total: 1m 44s	remaining: 2m 46s
# 385:	learn: 0.4842443	total: 1m 44s	remaining: 2m 46s
# 386:	learn: 0.4841478	total: 1m 44s	remaining: 2m 46s
# 387:	learn: 0.4840480	total: 1m 45s	remaining: 2m 45s
# 388:	learn: 0.4840025	total: 1m 45s	remaining: 2m 45s
# 389:	learn: 0.4838688	total: 1m 45s	remaining: 2m 45s
# 390:	learn: 0.4838095	total: 1m 46s	remaining: 2m 45s
# 391:	learn: 0.4837425	total: 1m 46s	remaining: 2m 44s
# 392:	learn: 0.4836323	total: 1m 46s	remaining: 2m 44s
# 393:	learn: 0.4835540	total: 1m 46s	remaining: 2m 44s
# 394:	learn: 0.4834503	total: 1m 47s	remaining: 2m 44s
# 395:	learn: 0.4833773	total: 1m 47s	remaining: 2m 43s
# 396:	learn: 0.4832879	total: 1m 47s	remaining: 2m 43s
# 397:	learn: 0.4832147	total: 1m 47s	remaining: 2m 43s
# 398:	learn: 0.4831608	total: 1m 48s	remaining: 2m 43s
# 399:	learn: 0.4830592	total: 1m 48s	remaining: 2m 42s
# 400:	learn: 0.4829485	total: 1m 48s	remaining: 2m 42s
# 401:	learn: 0.4828006	total: 1m 48s	remaining: 2m 42s
# 402:	learn: 0.4827223	total: 1m 49s	remaining: 2m 41s
# 403:	learn: 0.4825846	total: 1m 49s	remaining: 2m 41s
# 404:	learn: 0.4824438	total: 1m 49s	remaining: 2m 41s
# 405:	learn: 0.4823623	total: 1m 49s	remaining: 2m 40s
# 406:	learn: 0.4822510	total: 1m 50s	remaining: 2m 40s
# 407:	learn: 0.4821328	total: 1m 50s	remaining: 2m 40s
# 408:	learn: 0.4820765	total: 1m 50s	remaining: 2m 40s
# 409:	learn: 0.4820345	total: 1m 51s	remaining: 2m 39s
# 410:	learn: 0.4819207	total: 1m 51s	remaining: 2m 39s
# 411:	learn: 0.4818051	total: 1m 51s	remaining: 2m 39s
# 412:	learn: 0.4816899	total: 1m 51s	remaining: 2m 39s
# 413:	learn: 0.4816019	total: 1m 52s	remaining: 2m 38s
# 414:	learn: 0.4815166	total: 1m 52s	remaining: 2m 38s
# 415:	learn: 0.4814284	total: 1m 52s	remaining: 2m 38s
# 416:	learn: 0.4813433	total: 1m 52s	remaining: 2m 37s
# 417:	learn: 0.4812457	total: 1m 53s	remaining: 2m 37s
# 418:	learn: 0.4811700	total: 1m 53s	remaining: 2m 37s
# 419:	learn: 0.4810736	total: 1m 53s	remaining: 2m 37s
# 420:	learn: 0.4809858	total: 1m 54s	remaining: 2m 36s
# 421:	learn: 0.4809445	total: 1m 54s	remaining: 2m 36s
# 422:	learn: 0.4808579	total: 1m 54s	remaining: 2m 36s
# 423:	learn: 0.4807401	total: 1m 54s	remaining: 2m 36s
# 424:	learn: 0.4806406	total: 1m 55s	remaining: 2m 36s
# 425:	learn: 0.4805411	total: 1m 55s	remaining: 2m 35s
# 426:	learn: 0.4804543	total: 1m 55s	remaining: 2m 35s
# 427:	learn: 0.4803568	total: 1m 56s	remaining: 2m 35s
# 428:	learn: 0.4802605	total: 1m 56s	remaining: 2m 34s
# 429:	learn: 0.4802060	total: 1m 56s	remaining: 2m 34s
# 430:	learn: 0.4801486	total: 1m 56s	remaining: 2m 34s
# 431:	learn: 0.4800490	total: 1m 57s	remaining: 2m 34s
# 432:	learn: 0.4799613	total: 1m 57s	remaining: 2m 33s
# 433:	learn: 0.4798392	total: 1m 57s	remaining: 2m 33s
# 434:	learn: 0.4797746	total: 1m 58s	remaining: 2m 33s
# 435:	learn: 0.4796676	total: 1m 58s	remaining: 2m 33s
# 436:	learn: 0.4795213	total: 1m 58s	remaining: 2m 32s
# 437:	learn: 0.4794091	total: 1m 58s	remaining: 2m 32s
# 438:	learn: 0.4793158	total: 1m 59s	remaining: 2m 32s
# 439:	learn: 0.4792242	total: 1m 59s	remaining: 2m 32s
# 440:	learn: 0.4791150	total: 1m 59s	remaining: 2m 31s
# 441:	learn: 0.4790146	total: 2m	remaining: 2m 31s
# 442:	learn: 0.4789220	total: 2m	remaining: 2m 31s
# 443:	learn: 0.4788219	total: 2m	remaining: 2m 31s
# 444:	learn: 0.4787555	total: 2m 1s	remaining: 2m 30s
# 445:	learn: 0.4786496	total: 2m 1s	remaining: 2m 30s
# 446:	learn: 0.4785736	total: 2m 1s	remaining: 2m 30s
# 447:	learn: 0.4785031	total: 2m 1s	remaining: 2m 30s
# 448:	learn: 0.4784185	total: 2m 2s	remaining: 2m 29s
# 449:	learn: 0.4783206	total: 2m 2s	remaining: 2m 29s
# 450:	learn: 0.4782895	total: 2m 2s	remaining: 2m 29s
# 451:	learn: 0.4781668	total: 2m 2s	remaining: 2m 28s
# 452:	learn: 0.4780833	total: 2m 2s	remaining: 2m 28s
# 453:	learn: 0.4780181	total: 2m 3s	remaining: 2m 28s
# 454:	learn: 0.4779371	total: 2m 3s	remaining: 2m 27s
# 455:	learn: 0.4778181	total: 2m 3s	remaining: 2m 27s
# 456:	learn: 0.4777220	total: 2m 3s	remaining: 2m 27s
# 457:	learn: 0.4776237	total: 2m 4s	remaining: 2m 26s
# 458:	learn: 0.4775091	total: 2m 4s	remaining: 2m 26s
# 459:	learn: 0.4774295	total: 2m 4s	remaining: 2m 26s
# 460:	learn: 0.4773157	total: 2m 5s	remaining: 2m 26s
# 461:	learn: 0.4772151	total: 2m 5s	remaining: 2m 26s
# 462:	learn: 0.4771478	total: 2m 5s	remaining: 2m 26s
# 463:	learn: 0.4770597	total: 2m 6s	remaining: 2m 25s
# 464:	learn: 0.4769532	total: 2m 6s	remaining: 2m 25s
# 465:	learn: 0.4768486	total: 2m 6s	remaining: 2m 25s
# 466:	learn: 0.4767766	total: 2m 7s	remaining: 2m 25s
# 467:	learn: 0.4767010	total: 2m 7s	remaining: 2m 24s
# 468:	learn: 0.4766459	total: 2m 7s	remaining: 2m 24s
# 469:	learn: 0.4765380	total: 2m 8s	remaining: 2m 24s
# 470:	learn: 0.4764049	total: 2m 8s	remaining: 2m 24s
# 471:	learn: 0.4762759	total: 2m 8s	remaining: 2m 24s
# 472:	learn: 0.4761814	total: 2m 9s	remaining: 2m 24s
# 473:	learn: 0.4760830	total: 2m 9s	remaining: 2m 23s
# 474:	learn: 0.4760153	total: 2m 9s	remaining: 2m 23s
# 475:	learn: 0.4758885	total: 2m 10s	remaining: 2m 23s
# 476:	learn: 0.4757815	total: 2m 10s	remaining: 2m 23s
# 477:	learn: 0.4757182	total: 2m 10s	remaining: 2m 22s
# 478:	learn: 0.4756100	total: 2m 11s	remaining: 2m 22s
# 479:	learn: 0.4755004	total: 2m 11s	remaining: 2m 22s
# 480:	learn: 0.4753896	total: 2m 11s	remaining: 2m 22s
# 481:	learn: 0.4752706	total: 2m 12s	remaining: 2m 22s
# 482:	learn: 0.4751439	total: 2m 12s	remaining: 2m 21s
# 483:	learn: 0.4750602	total: 2m 12s	remaining: 2m 21s
# 484:	learn: 0.4749956	total: 2m 12s	remaining: 2m 21s
# 485:	learn: 0.4749053	total: 2m 13s	remaining: 2m 20s
# 486:	learn: 0.4748085	total: 2m 13s	remaining: 2m 20s
# 487:	learn: 0.4747349	total: 2m 13s	remaining: 2m 20s
# 488:	learn: 0.4746415	total: 2m 14s	remaining: 2m 20s
# 489:	learn: 0.4745290	total: 2m 14s	remaining: 2m 19s
# 490:	learn: 0.4744469	total: 2m 14s	remaining: 2m 19s
# 491:	learn: 0.4743693	total: 2m 14s	remaining: 2m 19s
# 492:	learn: 0.4743010	total: 2m 15s	remaining: 2m 18s
# 493:	learn: 0.4742246	total: 2m 15s	remaining: 2m 18s
# 494:	learn: 0.4741196	total: 2m 15s	remaining: 2m 18s
# 495:	learn: 0.4740127	total: 2m 15s	remaining: 2m 18s
# 496:	learn: 0.4739110	total: 2m 16s	remaining: 2m 17s
# 497:	learn: 0.4738348	total: 2m 16s	remaining: 2m 17s
# 498:	learn: 0.4737300	total: 2m 16s	remaining: 2m 17s
# 499:	learn: 0.4736232	total: 2m 17s	remaining: 2m 17s
# 500:	learn: 0.4735323	total: 2m 17s	remaining: 2m 16s
# 501:	learn: 0.4734439	total: 2m 17s	remaining: 2m 16s
# 502:	learn: 0.4733212	total: 2m 18s	remaining: 2m 16s
# 503:	learn: 0.4732158	total: 2m 18s	remaining: 2m 16s
# 504:	learn: 0.4731302	total: 2m 18s	remaining: 2m 16s
# 505:	learn: 0.4730821	total: 2m 19s	remaining: 2m 15s
# 506:	learn: 0.4730052	total: 2m 19s	remaining: 2m 15s
# 507:	learn: 0.4729604	total: 2m 19s	remaining: 2m 15s
# 508:	learn: 0.4728887	total: 2m 20s	remaining: 2m 15s
# 509:	learn: 0.4727943	total: 2m 20s	remaining: 2m 14s
# 510:	learn: 0.4727061	total: 2m 20s	remaining: 2m 14s
# 511:	learn: 0.4726271	total: 2m 20s	remaining: 2m 14s
# 512:	learn: 0.4725803	total: 2m 21s	remaining: 2m 13s
# 513:	learn: 0.4725046	total: 2m 21s	remaining: 2m 13s
# 514:	learn: 0.4724200	total: 2m 21s	remaining: 2m 13s
# 515:	learn: 0.4723179	total: 2m 22s	remaining: 2m 13s
# 516:	learn: 0.4722385	total: 2m 22s	remaining: 2m 13s
# 517:	learn: 0.4721261	total: 2m 22s	remaining: 2m 12s
# 518:	learn: 0.4720364	total: 2m 23s	remaining: 2m 12s
# 519:	learn: 0.4719525	total: 2m 23s	remaining: 2m 12s
# 520:	learn: 0.4718611	total: 2m 23s	remaining: 2m 12s
# 521:	learn: 0.4718055	total: 2m 23s	remaining: 2m 11s
# 522:	learn: 0.4717443	total: 2m 24s	remaining: 2m 11s
# 523:	learn: 0.4716648	total: 2m 24s	remaining: 2m 11s
# 524:	learn: 0.4715582	total: 2m 24s	remaining: 2m 10s
# 525:	learn: 0.4714636	total: 2m 24s	remaining: 2m 10s
# 526:	learn: 0.4713658	total: 2m 25s	remaining: 2m 10s
# 527:	learn: 0.4712789	total: 2m 25s	remaining: 2m 9s
# 528:	learn: 0.4711589	total: 2m 25s	remaining: 2m 9s
# 529:	learn: 0.4710947	total: 2m 25s	remaining: 2m 9s
# 530:	learn: 0.4710378	total: 2m 26s	remaining: 2m 9s
# 531:	learn: 0.4709686	total: 2m 26s	remaining: 2m 8s
# 532:	learn: 0.4708793	total: 2m 26s	remaining: 2m 8s
# 533:	learn: 0.4708444	total: 2m 27s	remaining: 2m 8s
# 534:	learn: 0.4707692	total: 2m 27s	remaining: 2m 8s
# 535:	learn: 0.4706697	total: 2m 27s	remaining: 2m 7s
# 536:	learn: 0.4706217	total: 2m 27s	remaining: 2m 7s
# 537:	learn: 0.4705309	total: 2m 28s	remaining: 2m 7s
# 538:	learn: 0.4704315	total: 2m 28s	remaining: 2m 7s
# 539:	learn: 0.4703624	total: 2m 28s	remaining: 2m 6s
# 540:	learn: 0.4702639	total: 2m 29s	remaining: 2m 6s
# 541:	learn: 0.4701705	total: 2m 29s	remaining: 2m 6s
# 542:	learn: 0.4700979	total: 2m 29s	remaining: 2m 5s
# 543:	learn: 0.4700200	total: 2m 29s	remaining: 2m 5s
# 544:	learn: 0.4699448	total: 2m 29s	remaining: 2m 5s
# 545:	learn: 0.4698562	total: 2m 30s	remaining: 2m 4s
# 546:	learn: 0.4697612	total: 2m 30s	remaining: 2m 4s
# 547:	learn: 0.4696401	total: 2m 30s	remaining: 2m 4s
# 548:	learn: 0.4695872	total: 2m 30s	remaining: 2m 4s
# 549:	learn: 0.4695217	total: 2m 31s	remaining: 2m 3s
# 550:	learn: 0.4693957	total: 2m 31s	remaining: 2m 3s
# 551:	learn: 0.4693034	total: 2m 31s	remaining: 2m 3s
# 552:	learn: 0.4691878	total: 2m 31s	remaining: 2m 2s
# 553:	learn: 0.4690585	total: 2m 32s	remaining: 2m 2s
# 554:	learn: 0.4689385	total: 2m 32s	remaining: 2m 2s
# 555:	learn: 0.4688128	total: 2m 32s	remaining: 2m 2s
# 556:	learn: 0.4687835	total: 2m 33s	remaining: 2m 1s
# 557:	learn: 0.4687098	total: 2m 33s	remaining: 2m 1s
# 558:	learn: 0.4686449	total: 2m 33s	remaining: 2m 1s
# 559:	learn: 0.4685579	total: 2m 33s	remaining: 2m
# 560:	learn: 0.4684666	total: 2m 34s	remaining: 2m
# 561:	learn: 0.4683716	total: 2m 34s	remaining: 2m
# 562:	learn: 0.4682720	total: 2m 34s	remaining: 2m
# 563:	learn: 0.4682106	total: 2m 34s	remaining: 1m 59s
# 564:	learn: 0.4681634	total: 2m 35s	remaining: 1m 59s
# 565:	learn: 0.4680538	total: 2m 35s	remaining: 1m 59s
# 566:	learn: 0.4679826	total: 2m 35s	remaining: 1m 58s
# 567:	learn: 0.4679218	total: 2m 36s	remaining: 1m 58s
# 568:	learn: 0.4678591	total: 2m 36s	remaining: 1m 58s
# 569:	learn: 0.4677877	total: 2m 36s	remaining: 1m 58s
# 570:	learn: 0.4676863	total: 2m 37s	remaining: 1m 58s
# 571:	learn: 0.4675959	total: 2m 37s	remaining: 1m 57s
# 572:	learn: 0.4674808	total: 2m 37s	remaining: 1m 57s
# 573:	learn: 0.4673982	total: 2m 38s	remaining: 1m 57s
# 574:	learn: 0.4673266	total: 2m 38s	remaining: 1m 57s
# 575:	learn: 0.4672154	total: 2m 38s	remaining: 1m 56s
# 576:	learn: 0.4671379	total: 2m 38s	remaining: 1m 56s
# 577:	learn: 0.4670493	total: 2m 39s	remaining: 1m 56s
# 578:	learn: 0.4669671	total: 2m 39s	remaining: 1m 55s
# 579:	learn: 0.4668406	total: 2m 39s	remaining: 1m 55s
# 580:	learn: 0.4667600	total: 2m 39s	remaining: 1m 55s
# 581:	learn: 0.4666905	total: 2m 40s	remaining: 1m 54s
# 582:	learn: 0.4666368	total: 2m 40s	remaining: 1m 54s
# 583:	learn: 0.4665503	total: 2m 40s	remaining: 1m 54s
# 584:	learn: 0.4664877	total: 2m 40s	remaining: 1m 54s
# 585:	learn: 0.4663840	total: 2m 41s	remaining: 1m 53s
# 586:	learn: 0.4662832	total: 2m 41s	remaining: 1m 53s
# 587:	learn: 0.4661794	total: 2m 41s	remaining: 1m 53s
# 588:	learn: 0.4661074	total: 2m 41s	remaining: 1m 52s
# 589:	learn: 0.4660152	total: 2m 42s	remaining: 1m 52s
# 590:	learn: 0.4659115	total: 2m 42s	remaining: 1m 52s
# 591:	learn: 0.4657893	total: 2m 42s	remaining: 1m 52s
# 592:	learn: 0.4657213	total: 2m 43s	remaining: 1m 51s
# 593:	learn: 0.4656468	total: 2m 43s	remaining: 1m 51s
# 594:	learn: 0.4655659	total: 2m 43s	remaining: 1m 51s
# 595:	learn: 0.4655164	total: 2m 43s	remaining: 1m 51s
# 596:	learn: 0.4654114	total: 2m 44s	remaining: 1m 50s
# 597:	learn: 0.4653484	total: 2m 44s	remaining: 1m 50s
# 598:	learn: 0.4652692	total: 2m 44s	remaining: 1m 50s
# 599:	learn: 0.4651769	total: 2m 44s	remaining: 1m 49s
# 600:	learn: 0.4651283	total: 2m 44s	remaining: 1m 49s
# 601:	learn: 0.4650540	total: 2m 45s	remaining: 1m 49s
# 602:	learn: 0.4649714	total: 2m 45s	remaining: 1m 48s
# 603:	learn: 0.4649100	total: 2m 45s	remaining: 1m 48s
# 604:	learn: 0.4648414	total: 2m 45s	remaining: 1m 48s
# 605:	learn: 0.4647775	total: 2m 46s	remaining: 1m 48s
# 606:	learn: 0.4647169	total: 2m 46s	remaining: 1m 47s
# 607:	learn: 0.4646209	total: 2m 46s	remaining: 1m 47s
# 608:	learn: 0.4645253	total: 2m 46s	remaining: 1m 47s
# 609:	learn: 0.4644089	total: 2m 47s	remaining: 1m 46s
# 610:	learn: 0.4643630	total: 2m 47s	remaining: 1m 46s
# 611:	learn: 0.4642970	total: 2m 47s	remaining: 1m 46s
# 612:	learn: 0.4641876	total: 2m 47s	remaining: 1m 45s
# 613:	learn: 0.4641040	total: 2m 48s	remaining: 1m 45s
# 614:	learn: 0.4640113	total: 2m 48s	remaining: 1m 45s
# 615:	learn: 0.4639617	total: 2m 48s	remaining: 1m 45s
# 616:	learn: 0.4638833	total: 2m 48s	remaining: 1m 44s
# 617:	learn: 0.4637693	total: 2m 49s	remaining: 1m 44s
# 618:	learn: 0.4637233	total: 2m 49s	remaining: 1m 44s
# 619:	learn: 0.4636367	total: 2m 49s	remaining: 1m 44s
# 620:	learn: 0.4635552	total: 2m 49s	remaining: 1m 43s
# 621:	learn: 0.4634837	total: 2m 50s	remaining: 1m 43s
# 622:	learn: 0.4634152	total: 2m 50s	remaining: 1m 43s
# 623:	learn: 0.4633255	total: 2m 50s	remaining: 1m 42s
# 624:	learn: 0.4632448	total: 2m 51s	remaining: 1m 42s
# 625:	learn: 0.4631591	total: 2m 51s	remaining: 1m 42s
# 626:	learn: 0.4630602	total: 2m 51s	remaining: 1m 42s
# 627:	learn: 0.4629528	total: 2m 51s	remaining: 1m 41s
# 628:	learn: 0.4628585	total: 2m 52s	remaining: 1m 41s
# 629:	learn: 0.4627719	total: 2m 52s	remaining: 1m 41s
# 630:	learn: 0.4626861	total: 2m 52s	remaining: 1m 40s
# 631:	learn: 0.4625598	total: 2m 52s	remaining: 1m 40s
# 632:	learn: 0.4624606	total: 2m 53s	remaining: 1m 40s
# 633:	learn: 0.4624008	total: 2m 53s	remaining: 1m 40s
# 634:	learn: 0.4623237	total: 2m 53s	remaining: 1m 39s
# 635:	learn: 0.4622563	total: 2m 53s	remaining: 1m 39s
# 636:	learn: 0.4621617	total: 2m 53s	remaining: 1m 39s
# 637:	learn: 0.4621003	total: 2m 54s	remaining: 1m 38s
# 638:	learn: 0.4619947	total: 2m 54s	remaining: 1m 38s
# 639:	learn: 0.4619122	total: 2m 54s	remaining: 1m 38s
# 640:	learn: 0.4617987	total: 2m 54s	remaining: 1m 37s
# 641:	learn: 0.4617126	total: 2m 55s	remaining: 1m 37s
# 642:	learn: 0.4616557	total: 2m 55s	remaining: 1m 37s
# 643:	learn: 0.4615574	total: 2m 55s	remaining: 1m 37s
# 644:	learn: 0.4614878	total: 2m 55s	remaining: 1m 36s
# 645:	learn: 0.4613919	total: 2m 56s	remaining: 1m 36s
# 646:	learn: 0.4612936	total: 2m 56s	remaining: 1m 36s
# 647:	learn: 0.4611954	total: 2m 56s	remaining: 1m 35s
# 648:	learn: 0.4611459	total: 2m 56s	remaining: 1m 35s
# 649:	learn: 0.4610412	total: 2m 57s	remaining: 1m 35s
# 650:	learn: 0.4609938	total: 2m 57s	remaining: 1m 35s
# 651:	learn: 0.4609539	total: 2m 57s	remaining: 1m 34s
# 652:	learn: 0.4608937	total: 2m 57s	remaining: 1m 34s
# 653:	learn: 0.4608098	total: 2m 58s	remaining: 1m 34s
# 654:	learn: 0.4607159	total: 2m 58s	remaining: 1m 33s
# 655:	learn: 0.4606570	total: 2m 58s	remaining: 1m 33s
# 656:	learn: 0.4606035	total: 2m 58s	remaining: 1m 33s
# 657:	learn: 0.4605441	total: 2m 58s	remaining: 1m 33s
# 658:	learn: 0.4604451	total: 2m 59s	remaining: 1m 32s
# 659:	learn: 0.4603172	total: 2m 59s	remaining: 1m 32s
# 660:	learn: 0.4602243	total: 2m 59s	remaining: 1m 32s
# 661:	learn: 0.4601607	total: 3m	remaining: 1m 31s
# 662:	learn: 0.4601093	total: 3m	remaining: 1m 31s
# 663:	learn: 0.4600565	total: 3m	remaining: 1m 31s
# 664:	learn: 0.4600098	total: 3m	remaining: 1m 31s
# 665:	learn: 0.4599619	total: 3m 1s	remaining: 1m 30s
# 666:	learn: 0.4598546	total: 3m 1s	remaining: 1m 30s
# 667:	learn: 0.4597824	total: 3m 1s	remaining: 1m 30s
# 668:	learn: 0.4596554	total: 3m 2s	remaining: 1m 30s
# 669:	learn: 0.4595670	total: 3m 2s	remaining: 1m 29s
# 670:	learn: 0.4594566	total: 3m 2s	remaining: 1m 29s
# 671:	learn: 0.4593610	total: 3m 2s	remaining: 1m 29s
# 672:	learn: 0.4592835	total: 3m 3s	remaining: 1m 29s
# 673:	learn: 0.4592195	total: 3m 3s	remaining: 1m 28s
# 674:	learn: 0.4591671	total: 3m 3s	remaining: 1m 28s
# 675:	learn: 0.4590387	total: 3m 4s	remaining: 1m 28s
# 676:	learn: 0.4589371	total: 3m 4s	remaining: 1m 27s
# 677:	learn: 0.4588642	total: 3m 4s	remaining: 1m 27s
# 678:	learn: 0.4587795	total: 3m 5s	remaining: 1m 27s
# 679:	learn: 0.4587144	total: 3m 5s	remaining: 1m 27s
# 680:	learn: 0.4586045	total: 3m 5s	remaining: 1m 27s
# 681:	learn: 0.4585684	total: 3m 6s	remaining: 1m 26s
# 682:	learn: 0.4585047	total: 3m 6s	remaining: 1m 26s
# 683:	learn: 0.4584323	total: 3m 6s	remaining: 1m 26s
# 684:	learn: 0.4583375	total: 3m 7s	remaining: 1m 26s
# 685:	learn: 0.4582826	total: 3m 7s	remaining: 1m 25s
# 686:	learn: 0.4582413	total: 3m 7s	remaining: 1m 25s
# 687:	learn: 0.4581783	total: 3m 7s	remaining: 1m 25s
# 688:	learn: 0.4580846	total: 3m 8s	remaining: 1m 24s
# 689:	learn: 0.4580128	total: 3m 8s	remaining: 1m 24s
# 690:	learn: 0.4579375	total: 3m 8s	remaining: 1m 24s
# 691:	learn: 0.4578802	total: 3m 8s	remaining: 1m 24s
# 692:	learn: 0.4577768	total: 3m 9s	remaining: 1m 23s
# 693:	learn: 0.4576662	total: 3m 9s	remaining: 1m 23s
# 694:	learn: 0.4575703	total: 3m 9s	remaining: 1m 23s
# 695:	learn: 0.4574863	total: 3m 9s	remaining: 1m 22s
# 696:	learn: 0.4574177	total: 3m 10s	remaining: 1m 22s
# 697:	learn: 0.4573570	total: 3m 10s	remaining: 1m 22s
# 698:	learn: 0.4572571	total: 3m 10s	remaining: 1m 22s
# 699:	learn: 0.4572252	total: 3m 10s	remaining: 1m 21s
# 700:	learn: 0.4571851	total: 3m 11s	remaining: 1m 21s
# 701:	learn: 0.4571549	total: 3m 11s	remaining: 1m 21s
# 702:	learn: 0.4570832	total: 3m 11s	remaining: 1m 21s
# 703:	learn: 0.4570288	total: 3m 12s	remaining: 1m 20s
# 704:	learn: 0.4569295	total: 3m 12s	remaining: 1m 20s
# 705:	learn: 0.4568551	total: 3m 12s	remaining: 1m 20s
# 706:	learn: 0.4567819	total: 3m 12s	remaining: 1m 19s
# 707:	learn: 0.4566861	total: 3m 13s	remaining: 1m 19s
# 708:	learn: 0.4566095	total: 3m 13s	remaining: 1m 19s
# 709:	learn: 0.4565240	total: 3m 13s	remaining: 1m 19s
# 710:	learn: 0.4564390	total: 3m 14s	remaining: 1m 18s
# 711:	learn: 0.4563478	total: 3m 14s	remaining: 1m 18s
# 712:	learn: 0.4562893	total: 3m 14s	remaining: 1m 18s
# 713:	learn: 0.4562081	total: 3m 15s	remaining: 1m 18s
# 714:	learn: 0.4561109	total: 3m 15s	remaining: 1m 17s
# 715:	learn: 0.4560386	total: 3m 16s	remaining: 1m 17s
# 716:	learn: 0.4559548	total: 3m 16s	remaining: 1m 17s
# 717:	learn: 0.4558973	total: 3m 16s	remaining: 1m 17s
# 718:	learn: 0.4558564	total: 3m 17s	remaining: 1m 17s
# 719:	learn: 0.4557915	total: 3m 17s	remaining: 1m 16s
# 720:	learn: 0.4557699	total: 3m 17s	remaining: 1m 16s
# 721:	learn: 0.4556566	total: 3m 17s	remaining: 1m 16s
# 722:	learn: 0.4555878	total: 3m 18s	remaining: 1m 15s
# 723:	learn: 0.4554866	total: 3m 18s	remaining: 1m 15s
# 724:	learn: 0.4554282	total: 3m 18s	remaining: 1m 15s
# 725:	learn: 0.4553417	total: 3m 19s	remaining: 1m 15s
# 726:	learn: 0.4552597	total: 3m 19s	remaining: 1m 14s
# 727:	learn: 0.4551755	total: 3m 19s	remaining: 1m 14s
# 728:	learn: 0.4551102	total: 3m 20s	remaining: 1m 14s
# 729:	learn: 0.4550378	total: 3m 20s	remaining: 1m 14s
# 730:	learn: 0.4549832	total: 3m 20s	remaining: 1m 13s
# 731:	learn: 0.4549102	total: 3m 20s	remaining: 1m 13s
# 732:	learn: 0.4548351	total: 3m 21s	remaining: 1m 13s
# 733:	learn: 0.4547227	total: 3m 21s	remaining: 1m 13s
# 734:	learn: 0.4546466	total: 3m 21s	remaining: 1m 12s
# 735:	learn: 0.4545979	total: 3m 22s	remaining: 1m 12s
# 736:	learn: 0.4545347	total: 3m 22s	remaining: 1m 12s
# 737:	learn: 0.4544479	total: 3m 22s	remaining: 1m 11s
# 738:	learn: 0.4544082	total: 3m 22s	remaining: 1m 11s
# 739:	learn: 0.4543610	total: 3m 23s	remaining: 1m 11s
# 740:	learn: 0.4542518	total: 3m 23s	remaining: 1m 11s
# 741:	learn: 0.4541791	total: 3m 23s	remaining: 1m 10s
# 742:	learn: 0.4540941	total: 3m 24s	remaining: 1m 10s
# 743:	learn: 0.4540376	total: 3m 24s	remaining: 1m 10s
# 744:	learn: 0.4539252	total: 3m 24s	remaining: 1m 10s
# 745:	learn: 0.4538613	total: 3m 24s	remaining: 1m 9s
# 746:	learn: 0.4537748	total: 3m 25s	remaining: 1m 9s
# 747:	learn: 0.4536697	total: 3m 25s	remaining: 1m 9s
# 748:	learn: 0.4536060	total: 3m 25s	remaining: 1m 8s
# 749:	learn: 0.4535437	total: 3m 26s	remaining: 1m 8s
# 750:	learn: 0.4534368	total: 3m 26s	remaining: 1m 8s
# 751:	learn: 0.4533898	total: 3m 26s	remaining: 1m 8s
# 752:	learn: 0.4533064	total: 3m 27s	remaining: 1m 7s
# 753:	learn: 0.4532370	total: 3m 27s	remaining: 1m 7s
# 754:	learn: 0.4531589	total: 3m 27s	remaining: 1m 7s
# 755:	learn: 0.4531001	total: 3m 28s	remaining: 1m 7s
# 756:	learn: 0.4529704	total: 3m 28s	remaining: 1m 6s
# 757:	learn: 0.4529150	total: 3m 28s	remaining: 1m 6s
# 758:	learn: 0.4528477	total: 3m 28s	remaining: 1m 6s
# 759:	learn: 0.4527582	total: 3m 29s	remaining: 1m 6s
# 760:	learn: 0.4527090	total: 3m 29s	remaining: 1m 5s
# 761:	learn: 0.4526313	total: 3m 29s	remaining: 1m 5s
# 762:	learn: 0.4525151	total: 3m 30s	remaining: 1m 5s
# 763:	learn: 0.4524129	total: 3m 30s	remaining: 1m 4s
# 764:	learn: 0.4523604	total: 3m 30s	remaining: 1m 4s
# 765:	learn: 0.4522762	total: 3m 31s	remaining: 1m 4s
# 766:	learn: 0.4522269	total: 3m 31s	remaining: 1m 4s
# 767:	learn: 0.4521619	total: 3m 31s	remaining: 1m 3s
# 768:	learn: 0.4520549	total: 3m 31s	remaining: 1m 3s
# 769:	learn: 0.4519743	total: 3m 32s	remaining: 1m 3s
# 770:	learn: 0.4519264	total: 3m 32s	remaining: 1m 3s
# 771:	learn: 0.4518531	total: 3m 32s	remaining: 1m 2s
# 772:	learn: 0.4517612	total: 3m 33s	remaining: 1m 2s
# 773:	learn: 0.4516692	total: 3m 33s	remaining: 1m 2s
# 774:	learn: 0.4515641	total: 3m 34s	remaining: 1m 2s
# 775:	learn: 0.4514442	total: 3m 34s	remaining: 1m 1s
# 776:	learn: 0.4513834	total: 3m 34s	remaining: 1m 1s
# 777:	learn: 0.4513177	total: 3m 34s	remaining: 1m 1s
# 778:	learn: 0.4512410	total: 3m 35s	remaining: 1m 1s
# 779:	learn: 0.4511724	total: 3m 35s	remaining: 1m
# 780:	learn: 0.4511330	total: 3m 35s	remaining: 1m
# 781:	learn: 0.4510470	total: 3m 36s	remaining: 1m
# 782:	learn: 0.4509508	total: 3m 36s	remaining: 1m
# 783:	learn: 0.4508598	total: 3m 36s	remaining: 59.8s
# 784:	learn: 0.4508250	total: 3m 37s	remaining: 59.5s
# 785:	learn: 0.4507606	total: 3m 37s	remaining: 59.2s
# 786:	learn: 0.4506861	total: 3m 37s	remaining: 58.9s
# 787:	learn: 0.4505853	total: 3m 38s	remaining: 58.7s
# 788:	learn: 0.4505602	total: 3m 38s	remaining: 58.5s
# 789:	learn: 0.4504816	total: 3m 39s	remaining: 58.2s
# 790:	learn: 0.4504365	total: 3m 39s	remaining: 58s
# 791:	learn: 0.4503529	total: 3m 39s	remaining: 57.7s
# 792:	learn: 0.4502471	total: 3m 40s	remaining: 57.5s
# 793:	learn: 0.4502018	total: 3m 40s	remaining: 57.2s
# 794:	learn: 0.4501164	total: 3m 40s	remaining: 57s
# 795:	learn: 0.4500687	total: 3m 41s	remaining: 56.7s
# 796:	learn: 0.4500029	total: 3m 41s	remaining: 56.4s
# 797:	learn: 0.4499602	total: 3m 41s	remaining: 56.1s
# 798:	learn: 0.4499018	total: 3m 42s	remaining: 55.9s
# 799:	learn: 0.4498153	total: 3m 42s	remaining: 55.6s
# 800:	learn: 0.4497733	total: 3m 42s	remaining: 55.3s
# 801:	learn: 0.4496788	total: 3m 42s	remaining: 55s
# 802:	learn: 0.4496138	total: 3m 43s	remaining: 54.7s
# 803:	learn: 0.4495277	total: 3m 43s	remaining: 54.5s
# 804:	learn: 0.4494845	total: 3m 43s	remaining: 54.2s
# 805:	learn: 0.4494087	total: 3m 43s	remaining: 53.9s
# 806:	learn: 0.4493012	total: 3m 44s	remaining: 53.6s
# 807:	learn: 0.4492152	total: 3m 44s	remaining: 53.3s
# 808:	learn: 0.4491534	total: 3m 44s	remaining: 53.1s
# 809:	learn: 0.4491029	total: 3m 45s	remaining: 52.8s
# 810:	learn: 0.4490232	total: 3m 45s	remaining: 52.5s
# 811:	learn: 0.4489720	total: 3m 45s	remaining: 52.3s
# 812:	learn: 0.4489132	total: 3m 46s	remaining: 52s
# 813:	learn: 0.4488442	total: 3m 46s	remaining: 51.7s
# 814:	learn: 0.4487678	total: 3m 46s	remaining: 51.5s
# 815:	learn: 0.4486893	total: 3m 46s	remaining: 51.2s
# 816:	learn: 0.4486002	total: 3m 47s	remaining: 50.9s
# 817:	learn: 0.4485731	total: 3m 47s	remaining: 50.6s
# 818:	learn: 0.4484946	total: 3m 47s	remaining: 50.4s
# 819:	learn: 0.4484154	total: 3m 48s	remaining: 50.1s
# 820:	learn: 0.4483489	total: 3m 48s	remaining: 49.8s
# 821:	learn: 0.4482956	total: 3m 48s	remaining: 49.5s
# 822:	learn: 0.4482262	total: 3m 49s	remaining: 49.3s
# 823:	learn: 0.4481794	total: 3m 49s	remaining: 49s
# 824:	learn: 0.4480927	total: 3m 49s	remaining: 48.7s
# 825:	learn: 0.4480038	total: 3m 49s	remaining: 48.4s
# 826:	learn: 0.4478916	total: 3m 50s	remaining: 48.2s
# 827:	learn: 0.4478523	total: 3m 50s	remaining: 47.9s
# 828:	learn: 0.4477435	total: 3m 50s	remaining: 47.6s
# 829:	learn: 0.4476920	total: 3m 51s	remaining: 47.3s
# 830:	learn: 0.4476254	total: 3m 51s	remaining: 47.1s
# 831:	learn: 0.4475625	total: 3m 51s	remaining: 46.8s
# 832:	learn: 0.4475139	total: 3m 52s	remaining: 46.5s
# 833:	learn: 0.4474328	total: 3m 52s	remaining: 46.3s
# 834:	learn: 0.4473511	total: 3m 52s	remaining: 46s
# 835:	learn: 0.4472924	total: 3m 53s	remaining: 45.7s
# 836:	learn: 0.4471829	total: 3m 53s	remaining: 45.5s
# 837:	learn: 0.4471206	total: 3m 53s	remaining: 45.2s
# 838:	learn: 0.4470526	total: 3m 53s	remaining: 44.9s
# 839:	learn: 0.4469773	total: 3m 54s	remaining: 44.6s
# 840:	learn: 0.4468853	total: 3m 54s	remaining: 44.3s
# 841:	learn: 0.4468052	total: 3m 54s	remaining: 44.1s
# 842:	learn: 0.4467141	total: 3m 55s	remaining: 43.8s
# 843:	learn: 0.4466267	total: 3m 55s	remaining: 43.5s
# 844:	learn: 0.4465215	total: 3m 55s	remaining: 43.2s
# 845:	learn: 0.4464578	total: 3m 55s	remaining: 42.9s
# 846:	learn: 0.4463641	total: 3m 56s	remaining: 42.7s
# 847:	learn: 0.4463189	total: 3m 56s	remaining: 42.4s
# 848:	learn: 0.4462193	total: 3m 56s	remaining: 42.1s
# 849:	learn: 0.4461685	total: 3m 57s	remaining: 41.8s
# 850:	learn: 0.4461207	total: 3m 57s	remaining: 41.6s
# 851:	learn: 0.4460422	total: 3m 57s	remaining: 41.3s
# 852:	learn: 0.4459611	total: 3m 57s	remaining: 41s
# 853:	learn: 0.4458814	total: 3m 58s	remaining: 40.7s
# 854:	learn: 0.4457864	total: 3m 58s	remaining: 40.5s
# 855:	learn: 0.4457055	total: 3m 58s	remaining: 40.2s
# 856:	learn: 0.4455912	total: 3m 59s	remaining: 39.9s
# 857:	learn: 0.4455224	total: 3m 59s	remaining: 39.6s
# 858:	learn: 0.4454482	total: 3m 59s	remaining: 39.4s
# 859:	learn: 0.4454089	total: 4m	remaining: 39.1s
# 860:	learn: 0.4453446	total: 4m	remaining: 38.8s
# 861:	learn: 0.4452797	total: 4m	remaining: 38.6s
# 862:	learn: 0.4452076	total: 4m 1s	remaining: 38.3s
# 863:	learn: 0.4451613	total: 4m 1s	remaining: 38s
# 864:	learn: 0.4450891	total: 4m 1s	remaining: 37.7s
# 865:	learn: 0.4450413	total: 4m 2s	remaining: 37.5s
# 866:	learn: 0.4449492	total: 4m 2s	remaining: 37.2s
# 867:	learn: 0.4448779	total: 4m 2s	remaining: 36.9s
# 868:	learn: 0.4448137	total: 4m 3s	remaining: 36.6s
# 869:	learn: 0.4447381	total: 4m 3s	remaining: 36.4s
# 870:	learn: 0.4446620	total: 4m 3s	remaining: 36.1s
# 871:	learn: 0.4445583	total: 4m 4s	remaining: 35.8s
# 872:	learn: 0.4444649	total: 4m 4s	remaining: 35.6s
# 873:	learn: 0.4443894	total: 4m 4s	remaining: 35.3s
# 874:	learn: 0.4443212	total: 4m 5s	remaining: 35s
# 875:	learn: 0.4442504	total: 4m 5s	remaining: 34.7s
# 876:	learn: 0.4441845	total: 4m 5s	remaining: 34.5s
# 877:	learn: 0.4441305	total: 4m 6s	remaining: 34.2s
# 878:	learn: 0.4440562	total: 4m 6s	remaining: 33.9s
# 879:	learn: 0.4439913	total: 4m 6s	remaining: 33.6s
# 880:	learn: 0.4439349	total: 4m 7s	remaining: 33.4s
# 881:	learn: 0.4438509	total: 4m 7s	remaining: 33.1s
# 882:	learn: 0.4437710	total: 4m 7s	remaining: 32.8s
# 883:	learn: 0.4437378	total: 4m 7s	remaining: 32.5s
# 884:	learn: 0.4436899	total: 4m 8s	remaining: 32.2s
# 885:	learn: 0.4436063	total: 4m 8s	remaining: 32s
# 886:	learn: 0.4435240	total: 4m 8s	remaining: 31.7s
# 887:	learn: 0.4434381	total: 4m 8s	remaining: 31.4s
# 888:	learn: 0.4433786	total: 4m 9s	remaining: 31.1s
# 889:	learn: 0.4433286	total: 4m 9s	remaining: 30.8s
# 890:	learn: 0.4432431	total: 4m 9s	remaining: 30.6s
# 891:	learn: 0.4431875	total: 4m 10s	remaining: 30.3s
# 892:	learn: 0.4431166	total: 4m 10s	remaining: 30s
# 893:	learn: 0.4430622	total: 4m 10s	remaining: 29.7s
# 894:	learn: 0.4429655	total: 4m 11s	remaining: 29.5s
# 895:	learn: 0.4428593	total: 4m 11s	remaining: 29.2s
# 896:	learn: 0.4427773	total: 4m 11s	remaining: 28.9s
# 897:	learn: 0.4426807	total: 4m 12s	remaining: 28.6s
# 898:	learn: 0.4426179	total: 4m 12s	remaining: 28.3s
# 899:	learn: 0.4425676	total: 4m 12s	remaining: 28.1s
# 900:	learn: 0.4425117	total: 4m 12s	remaining: 27.8s
# 901:	learn: 0.4424407	total: 4m 13s	remaining: 27.5s
# 902:	learn: 0.4423857	total: 4m 13s	remaining: 27.2s
# 903:	learn: 0.4422895	total: 4m 13s	remaining: 26.9s
# 904:	learn: 0.4421869	total: 4m 13s	remaining: 26.7s
# 905:	learn: 0.4421614	total: 4m 14s	remaining: 26.4s
# 906:	learn: 0.4421134	total: 4m 14s	remaining: 26.1s
# 907:	learn: 0.4420396	total: 4m 14s	remaining: 25.8s
# 908:	learn: 0.4419396	total: 4m 14s	remaining: 25.5s
# 909:	learn: 0.4418680	total: 4m 15s	remaining: 25.2s
# 910:	learn: 0.4418114	total: 4m 15s	remaining: 24.9s
# 911:	learn: 0.4417296	total: 4m 15s	remaining: 24.7s
# 912:	learn: 0.4416392	total: 4m 15s	remaining: 24.4s
# 913:	learn: 0.4415222	total: 4m 16s	remaining: 24.1s
# 914:	learn: 0.4414325	total: 4m 16s	remaining: 23.8s
# 915:	learn: 0.4413818	total: 4m 16s	remaining: 23.5s
# 916:	learn: 0.4413344	total: 4m 16s	remaining: 23.2s
# 917:	learn: 0.4412542	total: 4m 17s	remaining: 23s
# 918:	learn: 0.4412063	total: 4m 17s	remaining: 22.7s
# 919:	learn: 0.4411400	total: 4m 17s	remaining: 22.4s
# 920:	learn: 0.4410528	total: 4m 17s	remaining: 22.1s
# 921:	learn: 0.4410016	total: 4m 18s	remaining: 21.8s
# 922:	learn: 0.4409478	total: 4m 18s	remaining: 21.5s
# 923:	learn: 0.4408758	total: 4m 18s	remaining: 21.3s
# 924:	learn: 0.4407949	total: 4m 18s	remaining: 21s
# 925:	learn: 0.4407273	total: 4m 19s	remaining: 20.7s
# 926:	learn: 0.4406694	total: 4m 19s	remaining: 20.4s
# 927:	learn: 0.4405919	total: 4m 19s	remaining: 20.1s
# 928:	learn: 0.4405163	total: 4m 19s	remaining: 19.9s
# 929:	learn: 0.4404054	total: 4m 19s	remaining: 19.6s
# 930:	learn: 0.4403260	total: 4m 20s	remaining: 19.3s
# 931:	learn: 0.4402420	total: 4m 20s	remaining: 19s
# 932:	learn: 0.4401741	total: 4m 20s	remaining: 18.7s
# 933:	learn: 0.4400941	total: 4m 20s	remaining: 18.4s
# 934:	learn: 0.4400045	total: 4m 21s	remaining: 18.2s
# 935:	learn: 0.4399109	total: 4m 21s	remaining: 17.9s
# 936:	learn: 0.4398188	total: 4m 21s	remaining: 17.6s
# 937:	learn: 0.4397154	total: 4m 21s	remaining: 17.3s
# 938:	learn: 0.4396066	total: 4m 22s	remaining: 17s
# 939:	learn: 0.4395276	total: 4m 22s	remaining: 16.7s
# 940:	learn: 0.4394704	total: 4m 22s	remaining: 16.5s
# 941:	learn: 0.4393851	total: 4m 22s	remaining: 16.2s
# 942:	learn: 0.4392947	total: 4m 23s	remaining: 15.9s
# 943:	learn: 0.4392645	total: 4m 23s	remaining: 15.6s
# 944:	learn: 0.4391938	total: 4m 23s	remaining: 15.3s
# 945:	learn: 0.4391373	total: 4m 23s	remaining: 15.1s
# 946:	learn: 0.4390670	total: 4m 23s	remaining: 14.8s
# 947:	learn: 0.4390006	total: 4m 24s	remaining: 14.5s
# 948:	learn: 0.4389433	total: 4m 24s	remaining: 14.2s
# 949:	learn: 0.4388585	total: 4m 24s	remaining: 13.9s
# 950:	learn: 0.4387852	total: 4m 24s	remaining: 13.7s
# 951:	learn: 0.4387393	total: 4m 25s	remaining: 13.4s
# 952:	learn: 0.4387171	total: 4m 25s	remaining: 13.1s
# 953:	learn: 0.4386603	total: 4m 25s	remaining: 12.8s
# 954:	learn: 0.4386085	total: 4m 25s	remaining: 12.5s
# 955:	learn: 0.4385550	total: 4m 26s	remaining: 12.2s
# 956:	learn: 0.4384783	total: 4m 26s	remaining: 12s
# 957:	learn: 0.4383904	total: 4m 26s	remaining: 11.7s
# 958:	learn: 0.4383277	total: 4m 26s	remaining: 11.4s
# 959:	learn: 0.4382578	total: 4m 27s	remaining: 11.1s
# 960:	learn: 0.4382266	total: 4m 27s	remaining: 10.9s
# 961:	learn: 0.4381429	total: 4m 27s	remaining: 10.6s
# 962:	learn: 0.4380538	total: 4m 28s	remaining: 10.3s
# 963:	learn: 0.4379925	total: 4m 28s	remaining: 10s
# 964:	learn: 0.4379150	total: 4m 28s	remaining: 9.74s
# 965:	learn: 0.4378572	total: 4m 28s	remaining: 9.46s
# 966:	learn: 0.4377289	total: 4m 29s	remaining: 9.18s
# 967:	learn: 0.4376636	total: 4m 29s	remaining: 8.9s
# 968:	learn: 0.4375732	total: 4m 29s	remaining: 8.62s
# 969:	learn: 0.4375051	total: 4m 29s	remaining: 8.34s
# 970:	learn: 0.4374431	total: 4m 29s	remaining: 8.06s
# 971:	learn: 0.4373328	total: 4m 30s	remaining: 7.78s
# 972:	learn: 0.4372571	total: 4m 30s	remaining: 7.5s
# 973:	learn: 0.4372081	total: 4m 30s	remaining: 7.23s
# 974:	learn: 0.4371033	total: 4m 30s	remaining: 6.95s
# 975:	learn: 0.4370170	total: 4m 31s	remaining: 6.67s
# 976:	learn: 0.4369363	total: 4m 31s	remaining: 6.39s
# 977:	learn: 0.4368732	total: 4m 31s	remaining: 6.11s
# 978:	learn: 0.4368312	total: 4m 32s	remaining: 5.83s
# 979:	learn: 0.4367443	total: 4m 32s	remaining: 5.56s
# 980:	learn: 0.4366461	total: 4m 32s	remaining: 5.28s
# 981:	learn: 0.4365652	total: 4m 32s	remaining: 5s
# 982:	learn: 0.4364878	total: 4m 32s	remaining: 4.72s
# 983:	learn: 0.4363833	total: 4m 33s	remaining: 4.44s
# 984:	learn: 0.4362988	total: 4m 33s	remaining: 4.17s
# 985:	learn: 0.4362368	total: 4m 33s	remaining: 3.89s
# 986:	learn: 0.4361347	total: 4m 33s	remaining: 3.61s
# 987:	learn: 0.4360619	total: 4m 34s	remaining: 3.33s
# 988:	learn: 0.4360260	total: 4m 34s	remaining: 3.05s
# 989:	learn: 0.4359948	total: 4m 34s	remaining: 2.77s
# 990:	learn: 0.4359317	total: 4m 34s	remaining: 2.5s
# 991:	learn: 0.4358897	total: 4m 35s	remaining: 2.22s
# 992:	learn: 0.4358055	total: 4m 35s	remaining: 1.94s
# 993:	learn: 0.4357483	total: 4m 35s	remaining: 1.66s
# 994:	learn: 0.4356819	total: 4m 36s	remaining: 1.39s
# 995:	learn: 0.4356145	total: 4m 36s	remaining: 1.11s
# 996:	learn: 0.4355652	total: 4m 36s	remaining: 832ms
# 997:	learn: 0.4354713	total: 4m 36s	remaining: 555ms
# 998:	learn: 0.4354070	total: 4m 36s	remaining: 277ms
# 999:	learn: 0.4353563	total: 4m 37s	remaining: 0us

# %%
#print('Base features: mean={} scores={}'.format(cv_scores_base.mean(), cv_scores_base))
#print('Extended features: mean={} scores={}'.format(cv_scores_extended.mean(), cv_scores_extended))

# %%
#cv_scores_extended > cv_scores_base

# %% [markdown]
# В результате кросс-валидации выяснили: `RandomForestClassifier` на расширенном наборе признаков дает значительный прирост по качеству (в соответствии с метрикой ROC-AUC). Это логично — чем больше признаков, тем больше информации на вход получает модель, тем потенциально лучше она может предсказывать.

# %% [markdown]
# #### Подготовка решения

# %%
# Добавим те же признаки в тестовую выборку
df_test_features = pandas.read_csv('data_final/test_features.csv', index_col='match_id_hash')
df_test_features_extended = df_test_features.copy()
add_new_features(df_test_features_extended, 'data_final/test_matches.jsonl')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-058ff89502e2> in <module>()
#       1 # Добавим те же признаки в тестовую выборку
# ----> 2 df_test_features = pandas.read_csv('data_final/test_features.csv', index_col='match_id_hash')
#       3 df_test_features_extended = df_test_features.copy()
#       4 add_new_features(df_test_features_extended, 'data_final/test_matches.jsonl')
#
# NameError: name 'pandas' is not defined

# %%
#model = RandomForestClassifier()
#model.fit(X, y)
df_submission_base = pandas.DataFrame(
    {'radiant_win_prob': model.predict_proba(df_test_features_extended.values)[:, 1]}, 
    index=df_test_features.index,
)
df_submission_base.to_csv('submission_base_rf.csv')

# %%
model_extended = RandomForestClassifier()
model_extended.fit(df_train_features_extended.values, y)
df_submission_extended = pandas.DataFrame(
    {'radiant_win_pred': model.predict_proba(df_test_features_extended.values)[:, 1]}, 
    index=df_test_features.index,
)


submission_path = 'submissions/сatboost2.csv'

df_submission_extended.to_csv(submission_path)

# %% [markdown]
# ## Как построить таблицу признаков с нуля
#
# Ниже приведен код, которым организаторы построили таблицы `train_features.csv` и `test_features.csv`. Это быстрый и эффективный способ извлечь сразу много новых признаков. Вы можете модифицировать этот код, менять и добавлять свои признаки.
#
# Принцип работы кода следующий:
#
# 1. функция `extract_features_csv(match)` извлекает признаки из матча и записывает их в словарь
# 2. функция `extract_targets_csv(match, targets)` извлекает целевые переменные (в частности — `radiant_win`)
# 3. итерируя по файлу с матчами, собираем в список все извлеченные признаки и целевые переменные
# 4. при помощи `pandas.DataFrame.from_records()` создаем таблицы из построенных списокв

# %%
import collections

MATCH_FEATURES = [
    ('game_time', lambda m: m['game_time']),
    ('game_mode', lambda m: m['game_mode']),
    ('lobby_type', lambda m: m['lobby_type']),
    ('objectives_len', lambda m: len(m['objectives'])),
    ('chat_len', lambda m: len(m['chat'])),
]

PLAYER_FIELDS = [
    'hero_id',
    
    'kills',
    'deaths',
    'assists',
    'denies',
    
    'gold',
    'lh',
    'xp',
    'health',
    'max_health',
    'max_mana',
    'level',

    'x',
    'y',
    
    'stuns',
    'creeps_stacked',
    'camps_stacked',
    'rune_pickups',
    'firstblood_claimed',
    'teamfight_participation',
    'towers_killed',
    'roshans_killed',
    'obs_placed',
    'sen_placed',
]

def extract_features_csv(match):
    row = [
        ('match_id_hash', match['match_id_hash']),
    ]
    
    for field, f in MATCH_FEATURES:
        row.append((field, f(match)))
        
    for slot, player in enumerate(match['players']):
        if slot < 5:
            player_name = 'r%d' % (slot + 1)
        else:
            player_name = 'd%d' % (slot - 4)

        for field in PLAYER_FIELDS:
            column_name = '%s_%s' % (player_name, field)
            row.append((column_name, player[field]))
            
    return collections.OrderedDict(row)
    
def extract_targets_csv(match, targets):
    return collections.OrderedDict([('match_id_hash', match['match_id_hash'])] + [
        (field, targets[field])
        for field in ['game_time', 'radiant_win', 'duration', 'time_remaining', 'next_roshan_team']
    ])

# %%
# %%time

df_new_features = []
df_new_targets = []

for match in read_matches('data_final/train_matches.jsonl'):
    match_id_hash = match['match_id_hash']
    features = extract_features_csv(match)
    targets = extract_targets_csv(match, match['targets'])
    
    df_new_features.append(features)
    df_new_targets.append(targets)

# %%
df_new_features = pandas.DataFrame.from_records(df_new_features).set_index('match_id_hash')
df_new_targets = pandas.DataFrame.from_records(df_new_targets).set_index('match_id_hash')

# %%
df_new_features.head()

# %% [markdown]
# ## Конец
#
# - Задавайте вопросы по задаче на форуме
# - Экспериментируйте
# - Выбирайте лучшую модель
# - Отправляйте предсказания
# - Побеждайте!
